# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !git clone "https://github.com/srajan-kiyotaka/Pothole-Detection.git"
# Out:
# Cloning into 'Pothole-Detection'...
# remote: Enumerating objects: 29940, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 29940 (delta 11), reused 39 (delta 11), pack-reused 29893
# Receiving objects: 100% (29940/29940), 1.20 GiB | 39.62 MiB/s, done.
# Resolving deltas: 100% (1430/1430), done.
# Checking out files: 100% (30014/30014), done.

# %%
# Importing the csv file

import pandas as pd
import numpy as np

features = pd.read_csv(r"/content/Pothole-Detection/Dataset_Info.csv")

features.head(10)
# Out:
#               Image ID  Pothole  Number of Potholes Level  Unnamed: 4
# 0   pothole_image_1299        1                   3     B         NaN
# 1  pothole_image_10064        1                   1     A         NaN
# 2  pothole_image_10079        1                   1     A         NaN
# 3  pothole_image_10084        1                   1     A         NaN
# 4  pothole_image_10087        1                   2     A         NaN
# 5  pothole_image_10110        1                   1     A         NaN
# 6  pothole_image_10119        1                   1     A         NaN
# 7  pothole_image_10120        1                   1     A         NaN
# 8  pothole_image_10135        1                   1     A         NaN
# 9  pothole_image_10139        1                   1     A         NaN

# %%
features.isna().sum()
# Out:
# Image ID                  0
# Pothole                   0
# Number of Potholes        0
# Level                     0
# Unnamed: 4            30000
# dtype: int64

# %%
features = features.drop('Unnamed: 4', axis = 1)

# %%
features.head(10)
# Out:
#               Image ID  Pothole  Number of Potholes Level
# 0   pothole_image_1299        1                   3     B
# 1  pothole_image_10064        1                   1     A
# 2  pothole_image_10079        1                   1     A
# 3  pothole_image_10084        1                   1     A
# 4  pothole_image_10087        1                   2     A
# 5  pothole_image_10110        1                   1     A
# 6  pothole_image_10119        1                   1     A
# 7  pothole_image_10120        1                   1     A
# 8  pothole_image_10135        1                   1     A
# 9  pothole_image_10139        1                   1     A

# %%
features.isna().sum()
# Out:
# Image ID              0
# Pothole               0
# Number of Potholes    0
# Level                 0
# dtype: int64

# %%
all_image_names = features['Image ID']
features = features.drop('Image ID', axis = 1)

pothole_or_not = features['Pothole']
pothole_info = features['Number of Potholes']
pothole_level = features['Level']

pothole_or_not = pd.get_dummies(pothole_or_not, columns = ['Pothole'])
pothole_or_not.columns = ['Normal Road', 'Pothole']
pothole_level = pd.get_dummies(pothole_level, columns = ['Level'])

features = pothole_or_not.join(pothole_info)
features = features.join(pothole_level)

print(features.head(10))
# Out:
#    Normal Road  Pothole  Number of Potholes  A  B  C  S
# 0            0        1                   3  0  1  0  0
# 1            0        1                   1  1  0  0  0
# 2            0        1                   1  1  0  0  0
# 3            0        1                   1  1  0  0  0
# 4            0        1                   2  1  0  0  0
# 5            0        1                   1  1  0  0  0
# 6            0        1                   1  1  0  0  0
# 7            0        1                   1  1  0  0  0
# 8            0        1                   1  1  0  0  0
# 9            0        1                   1  1  0  0  0

# %%
from sklearn.utils import shuffle

image_names_shuffled, labels_shuffled = shuffle(all_image_names, features)

# %%
from sklearn.model_selection import train_test_split

X_train_image_names, X_test_image_names, y_train, y_test = train_test_split(
    image_names_shuffled, labels_shuffled, test_size=0.3, random_state=1)

# %%
type(y_train)
# Out:
# pandas.core.frame.DataFrame

# %%
train_pothole_or_not = y_train[['Normal Road', 'Pothole']]
train_pothole_info = y_train['Number of Potholes']
train_pothole_level = y_train[['A', 'B', 'C', 'S']]

test_pothole_or_not = y_test[['Normal Road', 'Pothole']]
test_pothole_info = y_test['Number of Potholes']
test_pothole_level = y_test[['A', 'B', 'C', 'S']]

# %%
y_train.shape
# Out:
# (21000, 7)

# %%
train_pothole_or_not = np.array(train_pothole_or_not)
train_pothole_info = np.array(train_pothole_info)
train_pothole_level = np.array(train_pothole_level)

test_pothole_or_not = np.array(test_pothole_or_not)
test_pothole_info = np.array(test_pothole_info)
test_pothole_level = np.array(test_pothole_level)

# %%
import cv2

def get_image(file_location):
    img = cv2.imread(file_location)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    img = img/255
    img = cv2.resize(img,(200, 200))
    return img

# %%
import keras
import numpy as np

class My_Custom_Generator(keras.utils.all_utils.Sequence) :
  
  def __init__(self, image_filenames, pothole, pothole_number, pothole_level, batch_size = 128) :
    self.image_filenames = image_filenames
    self.pothole = pothole
    self.pothole_number = pothole_number
    self.pothole_level = pothole_level
    self.batch_size = batch_size
    
    
  def __len__(self) :
    return (np.ceil(len(self.image_filenames) / float(self.batch_size))).astype(np.int)
  
  
  def __getitem__(self, idx) :
    batch_x = self.image_filenames[idx * self.batch_size : (idx+1) * self.batch_size]
    a = self.pothole[idx * self.batch_size : (idx+1) * self.batch_size]
    # b = self.pothole_number[idx * self.batch_size : (idx+1) * self.batch_size]
    c = self.pothole_level[idx * self.batch_size : (idx+1) * self.batch_size]
    batch_y = [np.array(a), np.array(c)] #, np.array(c)]

    return np.array([
            get_image(f'/content/Pothole-Detection/Unified Dataset/{str(file_name)}.jpg')
               for file_name in batch_x]), batch_y

# %%
batch_size = 90

my_training_batch_generator = My_Custom_Generator(X_train_image_names, train_pothole_or_not, train_pothole_info, train_pothole_level, batch_size)
my_validation_batch_generator = My_Custom_Generator(X_test_image_names, test_pothole_or_not, test_pothole_info, test_pothole_level, batch_size)

# %%
import tensorflow as tf
from keras.models import Sequential, Model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Input, Activation, Add, BatchNormalization

input_ = Input(shape = (200, 200, 1), name = "Input Layer")

conv_1 = Conv2D(64, kernel_size = (8, 8), name = "conv_1")(input_)
act_1 = Activation("relu", name = "act_1")(conv_1)
pool_1 = MaxPooling2D(pool_size = (8, 8), strides = (1, 1), padding = "valid", name = "pool_1")(act_1)

conv_2 = Conv2D(32, kernel_size = (2, 2), name = "conv_2")(pool_1)
act_2 = Activation("relu", name = "act_2")(conv_2)
pool_2 = MaxPooling2D(pool_size = (8, 8), strides = (1, 1), padding = "valid", name = "pool_2")(act_2)

conv_3 = Conv2D(16, kernel_size = (4, 4), name = "conv_3")(pool_2)
act_3 = Activation("relu", name = "act_3")(conv_3)
pool_3 = MaxPooling2D(pool_size = (16, 16), strides = (1, 1), padding = "valid", name = "pool_3")(act_3)

flat_1 = Flatten(name = "flat_1")(pool_3)

dense_1 = Dense(256, activation = "relu", name = "dense_1")(flat_1)
batch_1 = BatchNormalization(name = "batch_1")(dense_1)
dense_2 = Dense(64, activation = "relu", name = "dense_2")(batch_1)
batch_2 = BatchNormalization(name = "batch_2")(dense_2)
dense_3 = Dense(8, activation = "relu", name = "dense_3")(batch_2)
isPothole = Dense(2, activation = "softmax", name = "pothole")(dense_3)

conv_4 = Conv2D(8, kernel_size = (4, 4), name = "conv_4")(pool_3)
act_4 = Activation("relu", name = "act_4")(conv_4)
pool_4 = MaxPooling2D(pool_size = (8, 8), strides = (1, 1), padding = "valid", name = "pool_4")(act_4)

# flat_2 = Flatten(name = "flat_2")(pool_4)

# dense_4 = Dense(128, activation = "relu", name = "dense_4")(flat_2)
# batch_3 = BatchNormalization(name = "batch_3")(dense_4)
# add_1 = Add(name = "add_1")([batch_1, batch_3])

# dense_5 = Dense(64, activation = "relu", name = "dense_5")(add_1)
# batch_4 = BatchNormalization(name = "batch_4")(dense_5)
# pothole_num = Dense(1, activation = "relu", name = "pothole_number")(batch_2)

# conv_5 = Conv2D(16, kernel_size = (8, 8), name = "conv_5")(pool_4)
# act_5 = Activation("relu", name = "act_5")(conv_5)
# pool_5 = MaxPooling2D(pool_size = (4, 4), strides = (1, 1), padding = "valid", name = "pool_5")(act_5)

flat_2 = Flatten(name = "flat_2")(pool_4)

dense_4 = Dense(256, activation = "relu", name = "dense_4")(flat_2)
batch_5 = BatchNormalization(name = "batch_5")(dense_4)
add_2 = Add(name = "add_2")([batch_1, batch_5])
batch_6 = BatchNormalization(name = "batch_6")(add_2)
dense_5 = Dense(128, activation = "relu", name = "dense_5")(batch_6)
drop_2 = Dropout(rate = 0.4, name = "drop_2")(dense_5)
# add_3 = Add(name = "add_3")([batch_7, batch_2])
dense_6 = Dense(64, activation = "relu", name = "dense_6")(drop_2)
batch_7 = BatchNormalization(name = "batch_7")(dense_6)
dense_7 = Dense(32, activation = "relu", name = "dense_7")(batch_7)
drop_3 = Dropout(rate = 0.4, name = "drop_3")(dense_7)
dense_8 = Dense(16, activation = "relu", name = "dense_8")(drop_3)
pothole_level = Dense(4, activation = "softmax", name = "pothole_level")(dense_8)

model = Model(inputs = input_, outputs = [isPothole, pothole_level])

opt = tf.keras.optimizers.Adam(learning_rate = 0.001)

model.compile(
              loss = {
                  'pothole' : 'categorical_crossentropy',
                #   'pothole_number' : 'categorical_crossentropy'
                  'pothole_level' : 'categorical_crossentropy'
              },
              optimizer = opt,
              metrics = ['accuracy']
)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input Layer (InputLayer)       [(None, 200, 200, 1  0           []
#                                 )]
#
#  conv_1 (Conv2D)                (None, 193, 193, 64  4160        ['Input Layer[0][0]']
#                                 )
#
#  act_1 (Activation)             (None, 193, 193, 64  0           ['conv_1[0][0]']
#                                 )
#
#  pool_1 (MaxPooling2D)          (None, 186, 186, 64  0           ['act_1[0][0]']
#                                 )
#
#  conv_2 (Conv2D)                (None, 185, 185, 32  8224        ['pool_1[0][0]']
#                                 )
#
#  act_2 (Activation)             (None, 185, 185, 32  0           ['conv_2[0][0]']
#                                 )
#
#  pool_2 (MaxPooling2D)          (None, 178, 178, 32  0           ['act_2[0][0]']
#                                 )
#
#  conv_3 (Conv2D)                (None, 175, 175, 16  8208        ['pool_2[0][0]']
#                                 )
#
#  act_3 (Activation)             (None, 175, 175, 16  0           ['conv_3[0][0]']
#                                 )
#
#  pool_3 (MaxPooling2D)          (None, 160, 160, 16  0           ['act_3[0][0]']
#                                 )
#
#  conv_4 (Conv2D)                (None, 157, 157, 8)  2056        ['pool_3[0][0]']
#
#  act_4 (Activation)             (None, 157, 157, 8)  0           ['conv_4[0][0]']
#
#  pool_4 (MaxPooling2D)          (None, 150, 150, 8)  0           ['act_4[0][0]']
#
#  flat_1 (Flatten)               (None, 409600)       0           ['pool_3[0][0]']
#
#  flat_2 (Flatten)               (None, 180000)       0           ['pool_4[0][0]']
#
#  dense_1 (Dense)                (None, 256)          104857856   ['flat_1[0][0]']
#
#  dense_4 (Dense)                (None, 256)          46080256    ['flat_2[0][0]']
#
#  batch_1 (BatchNormalization)   (None, 256)          1024        ['dense_1[0][0]']
#
#  batch_5 (BatchNormalization)   (None, 256)          1024        ['dense_4[0][0]']
#
#  add_2 (Add)                    (None, 256)          0           ['batch_1[0][0]',
#                                                                   'batch_5[0][0]']
#
#  batch_6 (BatchNormalization)   (None, 256)          1024        ['add_2[0][0]']
#
#  dense_5 (Dense)                (None, 128)          32896       ['batch_6[0][0]']
#
#  drop_2 (Dropout)               (None, 128)          0           ['dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 64)           8256        ['drop_2[0][0]']
#
#  batch_7 (BatchNormalization)   (None, 64)           256         ['dense_6[0][0]']
#
#  dense_2 (Dense)                (None, 64)           16448       ['batch_1[0][0]']
#
#  dense_7 (Dense)                (None, 32)           2080        ['batch_7[0][0]']
#
#  batch_2 (BatchNormalization)   (None, 64)           256         ['dense_2[0][0]']
#
#  drop_3 (Dropout)               (None, 32)           0           ['dense_7[0][0]']
#
#  dense_3 (Dense)                (None, 8)            520         ['batch_2[0][0]']
#
#  dense_8 (Dense)                (None, 16)           528         ['drop_3[0][0]']
#
#  pothole (Dense)                (None, 2)            18          ['dense_3[0][0]']
#
#  pothole_level (Dense)          (None, 4)            68          ['dense_8[0][0]']
#
# ==================================================================================================
# Total params: 151,025,158
# Trainable params: 151,023,366
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
keras.utils.all_utils.plot_model(model, "model.png", show_shapes = True, show_layer_names = True)

# %%
# class Logger(keras.callbacks.Callback):
#   def on_epoch_end(self, epoch, logs=None):
#     pothole_accuracy = logs.get('pothole_accuracy')
#     pothole_number_accuracy = logs.get('pothole_number_accuracy')
#     pothole_level_accuracy = logs.get('pothole_level_accuracy')

#     val_pothole_accuracy = logs.get('val_pothole_accuracy')
#     val_pothole_number_accuracy = logs.get('val_pothole_number_accuracy')
#     val_pothole_level_accuracy = logs.get('val_pothole_level_accuracy')

#     print('='*30, epoch + 1, '='*30)
#     print(f'pothole_accuracy: {pothole_accuracy:.2f}, pothole_number_accuracy: {pothole_number_accuracy:.2f}, pothole_level_accuracy: {pothole_level_accuracy:.2f}')
#     print(f'val_pothole_accuracy: {val_pothole_accuracy:.2f}, val_pothole_number_accuracy: {val_pothole_number_accuracy:.2f}, val_pothole_level_accuracy:{val_pothole_level_accuracy:.2f}')

# %%
_ = model.fit_generator(generator=my_training_batch_generator,
                   steps_per_epoch = int(21000 // batch_size),
                   epochs = 50,
                #    verbose = False,
                   validation_data = my_validation_batch_generator,
                #    callbacks = [
                #                 Logger(),
                #                 keras.callbacks.TensorBoard(log_dir = './logs')
                #                 ],
                   validation_steps = int(9000 // batch_size))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# Epoch 1/50
# 233/233 [==============================] - 208s 821ms/step - loss: 1.1710 - pothole_loss: 0.3893 - pothole_level_loss: 0.7817 - pothole_accuracy: 0.8386 - pothole_level_accuracy: 0.7233 - val_loss: 4.2888 - val_pothole_loss: 1.6221 - val_pothole_level_loss: 2.6667 - val_pothole_accuracy: 0.7276 - val_pothole_level_accuracy: 0.7738
# Epoch 2/50
# 233/233 [==============================] - 186s 796ms/step - loss: 0.9251 - pothole_loss: 0.3188 - pothole_level_loss: 0.6063 - pothole_accuracy: 0.8794 - pothole_level_accuracy: 0.7965 - val_loss: 2.9518 - val_pothole_loss: 1.6152 - val_pothole_level_loss: 1.3367 - val_pothole_accuracy: 0.7276 - val_pothole_level_accuracy: 0.7739
# Epoch 3/50
# 233/233 [==============================] - 181s 778ms/step - loss: 0.8384 - pothole_loss: 0.2905 - pothole_level_loss: 0.5479 - pothole_accuracy: 0.8900 - pothole_level_accuracy: 0.8196 - val_loss: 1.1847 - val_pothole_loss: 0.3341 - val_pothole_level_loss: 0.8506 - val_pothole_accuracy: 0.8718 - val_pothole_level_accuracy: 0.7752
# Epoch 4/50
# 233/233 [==============================] - 182s 779ms/step - loss: 0.8834 - pothole_loss: 0.3179 - pothole_level_loss: 0.5656 - pothole_accuracy: 0.8770 - pothole_level_accuracy: 0.8110 - val_loss: 1.4068 - val_pothole_loss: 0.3169 - val_pothole_level_loss: 1.0899 - val_pothole_accuracy: 0.8704 - val_pothole_level_accuracy: 0.7739
# Epoch 5/50
# 233/233 [==============================] - 181s 778ms/step - loss: 0.7904 - pothole_loss: 0.2729 - pothole_level_loss: 0.5176 - pothole_accuracy: 0.8979 - pothole_level_accuracy: 0.8324 - val_loss: 0.8421 - val_pothole_loss: 0.3055 - val_pothole_level_loss: 0.5366 - val_pothole_accuracy: 0.8902 - val_pothole_level_accuracy: 0.8246
# Epoch 6/50
# 233/233 [==============================] - 181s 777ms/step - loss: 0.7486 - pothole_loss: 0.2544 - pothole_level_loss: 0.4943 - pothole_accuracy: 0.9040 - pothole_level_accuracy: 0.8405 - val_loss: 0.8067 - val_pothole_loss: 0.3322 - val_pothole_level_loss: 0.4745 - val_pothole_accuracy: 0.8618 - val_pothole_level_accuracy: 0.8482
# Epoch 7/50
# 233/233 [==============================] - 182s 780ms/step - loss: 0.7257 - pothole_loss: 0.2447 - pothole_level_loss: 0.4810 - pothole_accuracy: 0.9071 - pothole_level_accuracy: 0.8440 - val_loss: 1.0238 - val_pothole_loss: 0.4226 - val_pothole_level_loss: 0.6012 - val_pothole_accuracy: 0.8356 - val_pothole_level_accuracy: 0.7990
# Epoch 8/50
# 233/233 [==============================] - 182s 781ms/step - loss: 0.7089 - pothole_loss: 0.2364 - pothole_level_loss: 0.4725 - pothole_accuracy: 0.9102 - pothole_level_accuracy: 0.8468 - val_loss: 0.9651 - val_pothole_loss: 0.3562 - val_pothole_level_loss: 0.6089 - val_pothole_accuracy: 0.8670 - val_pothole_level_accuracy: 0.8093
# Epoch 9/50
# 233/233 [==============================] - 183s 784ms/step - loss: 0.6866 - pothole_loss: 0.2265 - pothole_level_loss: 0.4601 - pothole_accuracy: 0.9121 - pothole_level_accuracy: 0.8501 - val_loss: 0.7281 - val_pothole_loss: 0.2679 - val_pothole_level_loss: 0.4603 - val_pothole_accuracy: 0.9019 - val_pothole_level_accuracy: 0.8458
# Epoch 10/50
# 233/233 [==============================] - 197s 847ms/step - loss: 0.6792 - pothole_loss: 0.2242 - pothole_level_loss: 0.4550 - pothole_accuracy: 0.9132 - pothole_level_accuracy: 0.8527 - val_loss: 0.7154 - val_pothole_loss: 0.2849 - val_pothole_level_loss: 0.4305 - val_pothole_accuracy: 0.9037 - val_pothole_level_accuracy: 0.8628
# Epoch 11/50
# 233/233 [==============================] - 184s 787ms/step - loss: 0.6609 - pothole_loss: 0.2139 - pothole_level_loss: 0.4470 - pothole_accuracy: 0.9177 - pothole_level_accuracy: 0.8562 - val_loss: 0.7887 - val_pothole_loss: 0.3109 - val_pothole_level_loss: 0.4777 - val_pothole_accuracy: 0.8888 - val_pothole_level_accuracy: 0.8461
# Epoch 12/50
# 233/233 [==============================] - 183s 786ms/step - loss: 0.6474 - pothole_loss: 0.2072 - pothole_level_loss: 0.4402 - pothole_accuracy: 0.9202 - pothole_level_accuracy: 0.8573 - val_loss: 0.9220 - val_pothole_loss: 0.3120 - val_pothole_level_loss: 0.6100 - val_pothole_accuracy: 0.8794 - val_pothole_level_accuracy: 0.7898
# Epoch 13/50
# 233/233 [==============================] - 184s 788ms/step - loss: 0.6309 - pothole_loss: 0.1989 - pothole_level_loss: 0.4320 - pothole_accuracy: 0.9224 - pothole_level_accuracy: 0.8599 - val_loss: 0.9204 - val_pothole_loss: 0.3740 - val_pothole_level_loss: 0.5463 - val_pothole_accuracy: 0.8858 - val_pothole_level_accuracy: 0.8492
# Epoch 14/50
# 233/233 [==============================] - 183s 785ms/step - loss: 0.6179 - pothole_loss: 0.1940 - pothole_level_loss: 0.4239 - pothole_accuracy: 0.9246 - pothole_level_accuracy: 0.8627 - val_loss: 0.8945 - val_pothole_loss: 0.3308 - val_pothole_level_loss: 0.5637 - val_pothole_accuracy: 0.8946 - val_pothole_level_accuracy: 0.8254
# Epoch 15/50
# 233/233 [==============================] - 183s 785ms/step - loss: 0.6103 - pothole_loss: 0.1877 - pothole_level_loss: 0.4226 - pothole_accuracy: 0.9253 - pothole_level_accuracy: 0.8620 - val_loss: 0.7537 - val_pothole_loss: 0.2567 - val_pothole_level_loss: 0.4970 - val_pothole_accuracy: 0.9060 - val_pothole_level_accuracy: 0.8427
# Epoch 16/50
# 233/233 [==============================] - 183s 786ms/step - loss: 0.5923 - pothole_loss: 0.1807 - pothole_level_loss: 0.4116 - pothole_accuracy: 0.9288 - pothole_level_accuracy: 0.8644 - val_loss: 0.7806 - val_pothole_loss: 0.3146 - val_pothole_level_loss: 0.4660 - val_pothole_accuracy: 0.8841 - val_pothole_level_accuracy: 0.8570
# Epoch 17/50
# 233/233 [==============================] - 183s 784ms/step - loss: 0.6175 - pothole_loss: 0.1925 - pothole_level_loss: 0.4250 - pothole_accuracy: 0.9222 - pothole_level_accuracy: 0.8608 - val_loss: 0.9196 - val_pothole_loss: 0.3064 - val_pothole_level_loss: 0.6132 - val_pothole_accuracy: 0.8813 - val_pothole_level_accuracy: 0.7806
# Epoch 18/50
# 233/233 [==============================] - 183s 785ms/step - loss: 0.5720 - pothole_loss: 0.1674 - pothole_level_loss: 0.4046 - pothole_accuracy: 0.9321 - pothole_level_accuracy: 0.8661 - val_loss: 2.5705 - val_pothole_loss: 0.8097 - val_pothole_level_loss: 1.7608 - val_pothole_accuracy: 0.7722 - val_pothole_level_accuracy: 0.7829
# Epoch 19/50
# 233/233 [==============================] - 184s 791ms/step - loss: 0.5589 - pothole_loss: 0.1614 - pothole_level_loss: 0.3975 - pothole_accuracy: 0.9360 - pothole_level_accuracy: 0.8668 - val_loss: 0.7551 - val_pothole_loss: 0.2983 - val_pothole_level_loss: 0.4568 - val_pothole_accuracy: 0.8893 - val_pothole_level_accuracy: 0.8598
# Epoch 20/50
# 233/233 [==============================] - 184s 788ms/step - loss: 0.5402 - pothole_loss: 0.1521 - pothole_level_loss: 0.3880 - pothole_accuracy: 0.9389 - pothole_level_accuracy: 0.8703 - val_loss: 0.7861 - val_pothole_loss: 0.3169 - val_pothole_level_loss: 0.4692 - val_pothole_accuracy: 0.8760 - val_pothole_level_accuracy: 0.8482
# Epoch 21/50
# 233/233 [==============================] - 183s 786ms/step - loss: 0.5359 - pothole_loss: 0.1487 - pothole_level_loss: 0.3873 - pothole_accuracy: 0.9401 - pothole_level_accuracy: 0.8712 - val_loss: 0.7335 - val_pothole_loss: 0.2868 - val_pothole_level_loss: 0.4467 - val_pothole_accuracy: 0.8958 - val_pothole_level_accuracy: 0.8614
# Epoch 22/50
# 233/233 [==============================] - 183s 786ms/step - loss: 0.5164 - pothole_loss: 0.1373 - pothole_level_loss: 0.3791 - pothole_accuracy: 0.9442 - pothole_level_accuracy: 0.8725 - val_loss: 0.7532 - val_pothole_loss: 0.3172 - val_pothole_level_loss: 0.4360 - val_pothole_accuracy: 0.8811 - val_pothole_level_accuracy: 0.8586
# Epoch 23/50
# 233/233 [==============================] - 184s 788ms/step - loss: 0.5069 - pothole_loss: 0.1330 - pothole_level_loss: 0.3740 - pothole_accuracy: 0.9466 - pothole_level_accuracy: 0.8723 - val_loss: 1.5596 - val_pothole_loss: 0.4600 - val_pothole_level_loss: 1.0996 - val_pothole_accuracy: 0.8294 - val_pothole_level_accuracy: 0.6841
# Epoch 24/50
# 233/233 [==============================] - 183s 786ms/step - loss: 0.5063 - pothole_loss: 0.1316 - pothole_level_loss: 0.3747 - pothole_accuracy: 0.9473 - pothole_level_accuracy: 0.8745 - val_loss: 0.9907 - val_pothole_loss: 0.4693 - val_pothole_level_loss: 0.5214 - val_pothole_accuracy: 0.8159 - val_pothole_level_accuracy: 0.8386
# Epoch 25/50
# 233/233 [==============================] - 184s 789ms/step - loss: 0.4975 - pothole_loss: 0.1279 - pothole_level_loss: 0.3697 - pothole_accuracy: 0.9484 - pothole_level_accuracy: 0.8736 - val_loss: 3.1894 - val_pothole_loss: 1.5411 - val_pothole_level_loss: 1.6483 - val_pothole_accuracy: 0.8166 - val_pothole_level_accuracy: 0.8087
# Epoch 26/50
# 233/233 [==============================] - 184s 787ms/step - loss: 0.4864 - pothole_loss: 0.1236 - pothole_level_loss: 0.3628 - pothole_accuracy: 0.9500 - pothole_level_accuracy: 0.8757 - val_loss: 0.7779 - val_pothole_loss: 0.3212 - val_pothole_level_loss: 0.4568 - val_pothole_accuracy: 0.8973 - val_pothole_level_accuracy: 0.8714
# Epoch 27/50
# 233/233 [==============================] - 185s 794ms/step - loss: 0.4749 - pothole_loss: 0.1168 - pothole_level_loss: 0.3582 - pothole_accuracy: 0.9539 - pothole_level_accuracy: 0.8771 - val_loss: 0.8588 - val_pothole_loss: 0.3945 - val_pothole_level_loss: 0.4643 - val_pothole_accuracy: 0.8954 - val_pothole_level_accuracy: 0.8722
# Epoch 28/50
# 233/233 [==============================] - 183s 785ms/step - loss: 0.4710 - pothole_loss: 0.1173 - pothole_level_loss: 0.3537 - pothole_accuracy: 0.9521 - pothole_level_accuracy: 0.8762 - val_loss: 0.8638 - val_pothole_loss: 0.4101 - val_pothole_level_loss: 0.4537 - val_pothole_accuracy: 0.8577 - val_pothole_level_accuracy: 0.8520
# Epoch 29/50
# 233/233 [==============================] - 184s 788ms/step - loss: 0.4472 - pothole_loss: 0.1012 - pothole_level_loss: 0.3460 - pothole_accuracy: 0.9595 - pothole_level_accuracy: 0.8770 - val_loss: 1.0863 - val_pothole_loss: 0.4620 - val_pothole_level_loss: 0.6243 - val_pothole_accuracy: 0.8871 - val_pothole_level_accuracy: 0.8676
# Epoch 30/50
# 233/233 [==============================] - 183s 785ms/step - loss: 0.4537 - pothole_loss: 0.1035 - pothole_level_loss: 0.3502 - pothole_accuracy: 0.9576 - pothole_level_accuracy: 0.8784 - val_loss: 0.8552 - val_pothole_loss: 0.3477 - val_pothole_level_loss: 0.5075 - val_pothole_accuracy: 0.8881 - val_pothole_level_accuracy: 0.8464
# Epoch 31/50
# 233/233 [==============================] - 184s 787ms/step - loss: 0.4401 - pothole_loss: 0.0953 - pothole_level_loss: 0.3448 - pothole_accuracy: 0.9619 - pothole_level_accuracy: 0.8784 - val_loss: 0.8688 - val_pothole_loss: 0.4315 - val_pothole_level_loss: 0.4372 - val_pothole_accuracy: 0.8764 - val_pothole_level_accuracy: 0.8688
# Epoch 32/50
# 233/233 [==============================] - 183s 785ms/step - loss: 0.4227 - pothole_loss: 0.0860 - pothole_level_loss: 0.3367 - pothole_accuracy: 0.9664 - pothole_level_accuracy: 0.8798 - val_loss: 1.4504 - val_pothole_loss: 0.7934 - val_pothole_level_loss: 0.6570 - val_pothole_accuracy: 0.8603 - val_pothole_level_accuracy: 0.8212
# Epoch 33/50
# 233/233 [==============================] - 184s 788ms/step - loss: 0.4185 - pothole_loss: 0.0834 - pothole_level_loss: 0.3350 - pothole_accuracy: 0.9681 - pothole_level_accuracy: 0.8788 - val_loss: 0.9201 - val_pothole_loss: 0.4333 - val_pothole_level_loss: 0.4868 - val_pothole_accuracy: 0.8884 - val_pothole_level_accuracy: 0.8688
# Epoch 34/50
# 233/233 [==============================] - 183s 784ms/step - loss: 0.4035 - pothole_loss: 0.0786 - pothole_level_loss: 0.3249 - pothole_accuracy: 0.9687 - pothole_level_accuracy: 0.8818 - val_loss: 1.1752 - val_pothole_loss: 0.6118 - val_pothole_level_loss: 0.5634 - val_pothole_accuracy: 0.8489 - val_pothole_level_accuracy: 0.8490
# Epoch 35/50
# 233/233 [==============================] - 183s 787ms/step - loss: 0.4031 - pothole_loss: 0.0785 - pothole_level_loss: 0.3246 - pothole_accuracy: 0.9697 - pothole_level_accuracy: 0.8803 - val_loss: 0.8162 - val_pothole_loss: 0.3765 - val_pothole_level_loss: 0.4397 - val_pothole_accuracy: 0.9088 - val_pothole_level_accuracy: 0.8729
# Epoch 36/50
# 233/233 [==============================] - 183s 786ms/step - loss: 0.3848 - pothole_loss: 0.0685 - pothole_level_loss: 0.3164 - pothole_accuracy: 0.9743 - pothole_level_accuracy: 0.8847 - val_loss: 1.3139 - val_pothole_loss: 0.5144 - val_pothole_level_loss: 0.7995 - val_pothole_accuracy: 0.8990 - val_pothole_level_accuracy: 0.8709
# Epoch 37/50
# 233/233 [==============================] - 183s 784ms/step - loss: 0.3847 - pothole_loss: 0.0683 - pothole_level_loss: 0.3164 - pothole_accuracy: 0.9731 - pothole_level_accuracy: 0.8831 - val_loss: 0.9050 - val_pothole_loss: 0.4752 - val_pothole_level_loss: 0.4298 - val_pothole_accuracy: 0.8698 - val_pothole_level_accuracy: 0.8686
# Epoch 38/50
# 233/233 [==============================] - 183s 785ms/step - loss: 0.3681 - pothole_loss: 0.0624 - pothole_level_loss: 0.3057 - pothole_accuracy: 0.9769 - pothole_level_accuracy: 0.8852 - val_loss: 1.0092 - val_pothole_loss: 0.5189 - val_pothole_level_loss: 0.4903 - val_pothole_accuracy: 0.8753 - val_pothole_level_accuracy: 0.8409
# Epoch 39/50
# 233/233 [==============================] - 183s 783ms/step - loss: 0.3707 - pothole_loss: 0.0654 - pothole_level_loss: 0.3053 - pothole_accuracy: 0.9743 - pothole_level_accuracy: 0.8871 - val_loss: 1.6266 - val_pothole_loss: 0.9092 - val_pothole_level_loss: 0.7173 - val_pothole_accuracy: 0.8302 - val_pothole_level_accuracy: 0.8194
# Epoch 40/50
# 233/233 [==============================] - 183s 784ms/step - loss: 0.3680 - pothole_loss: 0.0645 - pothole_level_loss: 0.3035 - pothole_accuracy: 0.9765 - pothole_level_accuracy: 0.8876 - val_loss: 1.2398 - val_pothole_loss: 0.5244 - val_pothole_level_loss: 0.7154 - val_pothole_accuracy: 0.9001 - val_pothole_level_accuracy: 0.8580
# Epoch 41/50
# 233/233 [==============================] - 183s 783ms/step - loss: 0.3588 - pothole_loss: 0.0562 - pothole_level_loss: 0.3026 - pothole_accuracy: 0.9780 - pothole_level_accuracy: 0.8861 - val_loss: 1.0170 - val_pothole_loss: 0.4817 - val_pothole_level_loss: 0.5353 - val_pothole_accuracy: 0.8883 - val_pothole_level_accuracy: 0.8584
# Epoch 42/50
# 233/233 [==============================] - 183s 786ms/step - loss: 0.3486 - pothole_loss: 0.0525 - pothole_level_loss: 0.2961 - pothole_accuracy: 0.9798 - pothole_level_accuracy: 0.8869 - val_loss: 1.0908 - val_pothole_loss: 0.5063 - val_pothole_level_loss: 0.5845 - val_pothole_accuracy: 0.9024 - val_pothole_level_accuracy: 0.8544
# Epoch 43/50
# 233/233 [==============================] - 183s 785ms/step - loss: 0.3418 - pothole_loss: 0.0497 - pothole_level_loss: 0.2922 - pothole_accuracy: 0.9818 - pothole_level_accuracy: 0.8890 - val_loss: 0.9901 - val_pothole_loss: 0.4730 - val_pothole_level_loss: 0.5171 - val_pothole_accuracy: 0.8922 - val_pothole_level_accuracy: 0.8512
# Epoch 44/50
# 233/233 [==============================] - 184s 789ms/step - loss: 0.3412 - pothole_loss: 0.0495 - pothole_level_loss: 0.2918 - pothole_accuracy: 0.9818 - pothole_level_accuracy: 0.8891 - val_loss: 0.9195 - val_pothole_loss: 0.4695 - val_pothole_level_loss: 0.4500 - val_pothole_accuracy: 0.8759 - val_pothole_level_accuracy: 0.8648
# Epoch 45/50
# 233/233 [==============================] - 183s 783ms/step - loss: 0.3439 - pothole_loss: 0.0548 - pothole_level_loss: 0.2891 - pothole_accuracy: 0.9788 - pothole_level_accuracy: 0.8900 - val_loss: 2.7233 - val_pothole_loss: 0.5847 - val_pothole_level_loss: 2.1386 - val_pothole_accuracy: 0.8480 - val_pothole_level_accuracy: 0.8144
# Epoch 46/50
# 233/233 [==============================] - 183s 784ms/step - loss: 0.3276 - pothole_loss: 0.0469 - pothole_level_loss: 0.2807 - pothole_accuracy: 0.9825 - pothole_level_accuracy: 0.8931 - val_loss: 1.0051 - val_pothole_loss: 0.5067 - val_pothole_level_loss: 0.4984 - val_pothole_accuracy: 0.8949 - val_pothole_level_accuracy: 0.8594
# Epoch 47/50
# 233/233 [==============================] - 183s 783ms/step - loss: 0.3564 - pothole_loss: 0.0573 - pothole_level_loss: 0.2990 - pothole_accuracy: 0.9790 - pothole_level_accuracy: 0.8893 - val_loss: 1.1738 - val_pothole_loss: 0.6194 - val_pothole_level_loss: 0.5545 - val_pothole_accuracy: 0.8424 - val_pothole_level_accuracy: 0.8342
# Epoch 48/50
# 233/233 [==============================] - 183s 783ms/step - loss: 0.3268 - pothole_loss: 0.0427 - pothole_level_loss: 0.2841 - pothole_accuracy: 0.9836 - pothole_level_accuracy: 0.8897 - val_loss: 1.3238 - val_pothole_loss: 0.6250 - val_pothole_level_loss: 0.6988 - val_pothole_accuracy: 0.9130 - val_pothole_level_accuracy: 0.8559
# Epoch 49/50
# 233/233 [==============================] - 183s 783ms/step - loss: 0.3178 - pothole_loss: 0.0398 - pothole_level_loss: 0.2780 - pothole_accuracy: 0.9850 - pothole_level_accuracy: 0.8924 - val_loss: 1.2219 - val_pothole_loss: 0.7184 - val_pothole_level_loss: 0.5034 - val_pothole_accuracy: 0.8890 - val_pothole_level_accuracy: 0.8634
# Epoch 50/50
# 233/233 [==============================] - 183s 786ms/step - loss: 0.3103 - pothole_loss: 0.0391 - pothole_level_loss: 0.2711 - pothole_accuracy: 0.9864 - pothole_level_accuracy: 0.8945 - val_loss: 1.1129 - val_pothole_loss: 0.5163 - val_pothole_level_loss: 0.5965 - val_pothole_accuracy: 0.9087 - val_pothole_level_accuracy: 0.8480

# %%
model.save("pothole_detection_model_prototype_2_sgd.h5")

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

tflite_model_quant = converter.convert()
open("pothole_detection_model_prototype_2_sgd_lite.tflite" , "wb").write(tflite_model_quant)
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input Layer with unsupported characters which will be renamed to placeholder in the SavedModel.

# %%
# import tensorflow as tf

# model = tf.keras.models.load_model('/content/gdrive/MyDrive/A_I/pothole_detection_model_prototype_1_adam.h5')
# converter = tf.lite.TFLiteConverter.from_keras_model(model)
# tflite_model = converter.convert()
# open("/content/gdrive/MyDrive/A_I/pothole_detection_model_prototype_1_adam.tflite", "wb").write(tflite_model)
