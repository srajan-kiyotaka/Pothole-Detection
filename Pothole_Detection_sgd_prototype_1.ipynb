# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !git clone "https://github.com/srajan-kiyotaka/Pothole-Detection.git"
# Out:
# fatal: destination path 'Pothole-Detection' already exists and is not an empty directory.

# %%
# Importing the csv file

import pandas as pd
import numpy as np

features = pd.read_csv(r"/content/Pothole-Detection/Dataset_Info.csv")

features.head(10)
# Out:
#               Image ID  Pothole  Number of Potholes Level  Unnamed: 4
# 0   pothole_image_1299        1                   3     B         NaN
# 1  pothole_image_10064        1                   1     A         NaN
# 2  pothole_image_10079        1                   1     A         NaN
# 3  pothole_image_10084        1                   1     A         NaN
# 4  pothole_image_10087        1                   2     A         NaN
# 5  pothole_image_10110        1                   1     A         NaN
# 6  pothole_image_10119        1                   1     A         NaN
# 7  pothole_image_10120        1                   1     A         NaN
# 8  pothole_image_10135        1                   1     A         NaN
# 9  pothole_image_10139        1                   1     A         NaN

# %%
features.isna().sum()
# Out:
# Image ID                  0
# Pothole                   0
# Number of Potholes        0
# Level                     0
# Unnamed: 4            30000
# dtype: int64

# %%
features = features.drop('Unnamed: 4', axis = 1)

# %%
features.head(10)
# Out:
#               Image ID  Pothole  Number of Potholes Level
# 0   pothole_image_1299        1                   3     B
# 1  pothole_image_10064        1                   1     A
# 2  pothole_image_10079        1                   1     A
# 3  pothole_image_10084        1                   1     A
# 4  pothole_image_10087        1                   2     A
# 5  pothole_image_10110        1                   1     A
# 6  pothole_image_10119        1                   1     A
# 7  pothole_image_10120        1                   1     A
# 8  pothole_image_10135        1                   1     A
# 9  pothole_image_10139        1                   1     A

# %%
features.isna().sum()
# Out:
# Image ID              0
# Pothole               0
# Number of Potholes    0
# Level                 0
# dtype: int64

# %%
all_image_names = features['Image ID']
features = features.drop('Image ID', axis = 1)

pothole_or_not = features['Pothole']
pothole_info = features['Number of Potholes']
pothole_level = features['Level']

pothole_or_not = pd.get_dummies(pothole_or_not, columns = ['Pothole'])
pothole_or_not.columns = ['Normal Road', 'Pothole']
pothole_level = pd.get_dummies(pothole_level, columns = ['Level'])

features = pothole_or_not.join(pothole_info)
features = features.join(pothole_level)

print(features.head(10))
# Out:
#    Normal Road  Pothole  Number of Potholes  A  B  C  S
# 0            0        1                   3  0  1  0  0
# 1            0        1                   1  1  0  0  0
# 2            0        1                   1  1  0  0  0
# 3            0        1                   1  1  0  0  0
# 4            0        1                   2  1  0  0  0
# 5            0        1                   1  1  0  0  0
# 6            0        1                   1  1  0  0  0
# 7            0        1                   1  1  0  0  0
# 8            0        1                   1  1  0  0  0
# 9            0        1                   1  1  0  0  0

# %%
from sklearn.utils import shuffle

image_names_shuffled, labels_shuffled = shuffle(all_image_names, features)

# %%
from sklearn.model_selection import train_test_split

X_train_image_names, X_test_image_names, y_train, y_test = train_test_split(
    image_names_shuffled, labels_shuffled, test_size=0.3, random_state=1)

# %%
type(y_train)
# Out:
# pandas.core.frame.DataFrame

# %%
train_pothole_or_not = y_train[['Normal Road', 'Pothole']]
train_pothole_info = y_train['Number of Potholes']
train_pothole_level = y_train[['A', 'B', 'C', 'S']]

test_pothole_or_not = y_test[['Normal Road', 'Pothole']]
test_pothole_info = y_test['Number of Potholes']
test_pothole_level = y_test[['A', 'B', 'C', 'S']]

# %%
y_train.shape
# Out:
# (21000, 7)

# %%
train_pothole_or_not = np.array(train_pothole_or_not)
train_pothole_info = np.array(train_pothole_info)
train_pothole_level = np.array(train_pothole_level)

test_pothole_or_not = np.array(test_pothole_or_not)
test_pothole_info = np.array(test_pothole_info)
test_pothole_level = np.array(test_pothole_level)

# %%
import cv2

def get_image(file_location):
    img = cv2.imread(file_location)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    img = img/255
    img = cv2.resize(img,(200, 200))
    return img

# %%
import keras
import numpy as np

class My_Custom_Generator(keras.utils.all_utils.Sequence) :
  
  def __init__(self, image_filenames, pothole, pothole_number, pothole_level, batch_size = 128) :
    self.image_filenames = image_filenames
    self.pothole = pothole
    self.pothole_number = pothole_number
    self.pothole_level = pothole_level
    self.batch_size = batch_size
    
    
  def __len__(self) :
    return (np.ceil(len(self.image_filenames) / float(self.batch_size))).astype(np.int)
  
  
  def __getitem__(self, idx) :
    batch_x = self.image_filenames[idx * self.batch_size : (idx+1) * self.batch_size]
    a = self.pothole[idx * self.batch_size : (idx+1) * self.batch_size]
    # b = self.pothole_number[idx * self.batch_size : (idx+1) * self.batch_size]
    c = self.pothole_level[idx * self.batch_size : (idx+1) * self.batch_size]
    batch_y = [np.array(a), np.array(c)] #, np.array(c)]

    return np.array([
            get_image(f'/content/Pothole-Detection/Unified Dataset/{str(file_name)}.jpg')
               for file_name in batch_x]), batch_y

# %%
batch_size = 90

my_training_batch_generator = My_Custom_Generator(X_train_image_names, train_pothole_or_not, train_pothole_info, train_pothole_level, batch_size)
my_validation_batch_generator = My_Custom_Generator(X_test_image_names, test_pothole_or_not, test_pothole_info, test_pothole_level, batch_size)

# %%
import tensorflow as tf
from keras.models import Sequential, Model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Input, Activation, Add, BatchNormalization

input_ = Input(shape = (200, 200, 1), name = "Input Layer")

conv_1 = Conv2D(64, kernel_size = (8, 8), name = "conv_1")(input_)
act_1 = Activation("relu", name = "act_1")(conv_1)
pool_1 = MaxPooling2D(pool_size = (8, 8), strides = (1, 1), padding = "valid", name = "pool_1")(act_1)

conv_2 = Conv2D(32, kernel_size = (2, 2), name = "conv_2")(pool_1)
act_2 = Activation("relu", name = "act_2")(conv_2)
pool_2 = MaxPooling2D(pool_size = (8, 8), strides = (1, 1), padding = "valid", name = "pool_2")(act_2)

conv_3 = Conv2D(16, kernel_size = (4, 4), name = "conv_3")(pool_2)
act_3 = Activation("relu", name = "act_3")(conv_3)
pool_3 = MaxPooling2D(pool_size = (16, 16), strides = (1, 1), padding = "valid", name = "pool_3")(act_3)

flat_1 = Flatten(name = "flat_1")(pool_3)

dense_1 = Dense(128, activation = "relu", name = "dense_1")(flat_1)
batch_1 = BatchNormalization(name = "batch_1")(dense_1)
dense_2 = Dense(64, activation = "relu", name = "dense_2")(batch_1)
batch_2 = BatchNormalization(name = "batch_2")(dense_2)
dense_3 = Dense(32, activation = "relu", name = "dense_3")(batch_2)
isPothole = Dense(2, activation = "softmax", name = "pothole")(dense_3)

conv_4 = Conv2D(8, kernel_size = (4, 4), name = "conv_4")(pool_3)
act_4 = Activation("relu", name = "act_4")(conv_4)
pool_4 = MaxPooling2D(pool_size = (8, 8), strides = (1, 1), padding = "valid", name = "pool_4")(act_4)

# flat_2 = Flatten(name = "flat_2")(pool_4)

# dense_4 = Dense(128, activation = "relu", name = "dense_4")(flat_2)
# batch_3 = BatchNormalization(name = "batch_3")(dense_4)
# add_1 = Add(name = "add_1")([batch_1, batch_3])

# dense_5 = Dense(64, activation = "relu", name = "dense_5")(add_1)
# batch_4 = BatchNormalization(name = "batch_4")(dense_5)
# pothole_num = Dense(1, activation = "relu", name = "pothole_number")(batch_2)

# conv_5 = Conv2D(16, kernel_size = (8, 8), name = "conv_5")(pool_4)
# act_5 = Activation("relu", name = "act_5")(conv_5)
# pool_5 = MaxPooling2D(pool_size = (4, 4), strides = (1, 1), padding = "valid", name = "pool_5")(act_5)

flat_2 = Flatten(name = "flat_2")(pool_4)

dense_4 = Dense(128, activation = "relu", name = "dense_4")(flat_2)
batch_5 = BatchNormalization(name = "batch_5")(dense_4)
add_2 = Add(name = "add_2")([batch_1, batch_5])
batch_6 = BatchNormalization(name = "batch_6")(add_2)
dense_5 = Dense(64, activation = "relu", name = "dense_5")(batch_6)
drop_2 = Dropout(rate = 0.4, name = "drop_2")(dense_5)
# add_3 = Add(name = "add_3")([batch_7, batch_2])
dense_6 = Dense(32, activation = "relu", name = "dense_6")(drop_2)
batch_7 = BatchNormalization(name = "batch_7")(dense_6)
dense_7 = Dense(16, activation = "relu", name = "dense_7")(batch_7)
drop_3 = Dropout(rate = 0.4, name = "drop_3")(dense_7)
dense_8 = Dense(8, activation = "relu", name = "dense_8")(drop_3)
pothole_level = Dense(4, activation = "softmax", name = "pothole_level")(dense_8)

model = Model(inputs = input_, outputs = [isPothole, pothole_level])

opt = tf.keras.optimizers.SGD(learning_rate = 0.002)

model.compile(
              loss = {
                  'pothole' : 'categorical_crossentropy',
                #   'pothole_number' : 'categorical_crossentropy'
                  'pothole_level' : 'categorical_crossentropy'
              },
              optimizer = opt,
              metrics = ['accuracy']
)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input Layer (InputLayer)       [(None, 200, 200, 1  0           []
#                                 )]
#
#  conv_1 (Conv2D)                (None, 193, 193, 64  4160        ['Input Layer[0][0]']
#                                 )
#
#  act_1 (Activation)             (None, 193, 193, 64  0           ['conv_1[0][0]']
#                                 )
#
#  pool_1 (MaxPooling2D)          (None, 186, 186, 64  0           ['act_1[0][0]']
#                                 )
#
#  conv_2 (Conv2D)                (None, 185, 185, 32  8224        ['pool_1[0][0]']
#                                 )
#
#  act_2 (Activation)             (None, 185, 185, 32  0           ['conv_2[0][0]']
#                                 )
#
#  pool_2 (MaxPooling2D)          (None, 178, 178, 32  0           ['act_2[0][0]']
#                                 )
#
#  conv_3 (Conv2D)                (None, 175, 175, 16  8208        ['pool_2[0][0]']
#                                 )
#
#  act_3 (Activation)             (None, 175, 175, 16  0           ['conv_3[0][0]']
#                                 )
#
#  pool_3 (MaxPooling2D)          (None, 160, 160, 16  0           ['act_3[0][0]']
#                                 )
#
#  conv_4 (Conv2D)                (None, 157, 157, 8)  2056        ['pool_3[0][0]']
#
#  act_4 (Activation)             (None, 157, 157, 8)  0           ['conv_4[0][0]']
#
#  pool_4 (MaxPooling2D)          (None, 150, 150, 8)  0           ['act_4[0][0]']
#
#  flat_1 (Flatten)               (None, 409600)       0           ['pool_3[0][0]']
#
#  flat_2 (Flatten)               (None, 180000)       0           ['pool_4[0][0]']
#
#  dense_1 (Dense)                (None, 128)          52428928    ['flat_1[0][0]']
#
#  dense_4 (Dense)                (None, 128)          23040128    ['flat_2[0][0]']
#
#  batch_1 (BatchNormalization)   (None, 128)          512         ['dense_1[0][0]']
#
#  batch_5 (BatchNormalization)   (None, 128)          512         ['dense_4[0][0]']
#
#  add_2 (Add)                    (None, 128)          0           ['batch_1[0][0]',
#                                                                   'batch_5[0][0]']
#
#  batch_6 (BatchNormalization)   (None, 128)          512         ['add_2[0][0]']
#
#  dense_5 (Dense)                (None, 64)           8256        ['batch_6[0][0]']
#
#  drop_2 (Dropout)               (None, 64)           0           ['dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 32)           2080        ['drop_2[0][0]']
#
#  batch_7 (BatchNormalization)   (None, 32)           128         ['dense_6[0][0]']
#
#  dense_2 (Dense)                (None, 64)           8256        ['batch_1[0][0]']
#
#  dense_7 (Dense)                (None, 16)           528         ['batch_7[0][0]']
#
#  batch_2 (BatchNormalization)   (None, 64)           256         ['dense_2[0][0]']
#
#  drop_3 (Dropout)               (None, 16)           0           ['dense_7[0][0]']
#
#  dense_3 (Dense)                (None, 32)           2080        ['batch_2[0][0]']
#
#  dense_8 (Dense)                (None, 8)            136         ['drop_3[0][0]']
#
#  pothole (Dense)                (None, 2)            66          ['dense_3[0][0]']
#
#  pothole_level (Dense)          (None, 4)            36          ['dense_8[0][0]']
#
# ==================================================================================================
# Total params: 75,515,062
# Trainable params: 75,514,102
# Non-trainable params: 960
# __________________________________________________________________________________________________

# %%
keras.utils.all_utils.plot_model(model, "model.png", show_shapes = True, show_layer_names = True)

# %%
# class Logger(keras.callbacks.Callback):
#   def on_epoch_end(self, epoch, logs=None):
#     pothole_accuracy = logs.get('pothole_accuracy')
#     pothole_number_accuracy = logs.get('pothole_number_accuracy')
#     pothole_level_accuracy = logs.get('pothole_level_accuracy')

#     val_pothole_accuracy = logs.get('val_pothole_accuracy')
#     val_pothole_number_accuracy = logs.get('val_pothole_number_accuracy')
#     val_pothole_level_accuracy = logs.get('val_pothole_level_accuracy')

#     print('='*30, epoch + 1, '='*30)
#     print(f'pothole_accuracy: {pothole_accuracy:.2f}, pothole_number_accuracy: {pothole_number_accuracy:.2f}, pothole_level_accuracy: {pothole_level_accuracy:.2f}')
#     print(f'val_pothole_accuracy: {val_pothole_accuracy:.2f}, val_pothole_number_accuracy: {val_pothole_number_accuracy:.2f}, val_pothole_level_accuracy:{val_pothole_level_accuracy:.2f}')

# %%
_ = model.fit_generator(generator=my_training_batch_generator,
                   steps_per_epoch = int(21000 // batch_size),
                   epochs = 50,
                #    verbose = False,
                   validation_data = my_validation_batch_generator,
                #    callbacks = [
                #                 Logger(),
                #                 keras.callbacks.TensorBoard(log_dir = './logs')
                #                 ],
                   validation_steps = int(9000 // batch_size))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# Epoch 1/50
# 233/233 [==============================] - 202s 804ms/step - loss: 1.9519 - pothole_loss: 0.4017 - pothole_level_loss: 1.5502 - pothole_accuracy: 0.8305 - pothole_level_accuracy: 0.3215 - val_loss: 1.4848 - val_pothole_loss: 0.4446 - val_pothole_level_loss: 1.0402 - val_pothole_accuracy: 0.7680 - val_pothole_level_accuracy: 0.7650
# Epoch 2/50
# 233/233 [==============================] - 206s 882ms/step - loss: 1.2139 - pothole_loss: 0.3009 - pothole_level_loss: 0.9130 - pothole_accuracy: 0.8910 - pothole_level_accuracy: 0.7168 - val_loss: 1.1921 - val_pothole_loss: 0.4393 - val_pothole_level_loss: 0.7528 - val_pothole_accuracy: 0.7770 - val_pothole_level_accuracy: 0.7682
# Epoch 3/50
# 233/233 [==============================] - 191s 818ms/step - loss: 1.0070 - pothole_loss: 0.2697 - pothole_level_loss: 0.7373 - pothole_accuracy: 0.9042 - pothole_level_accuracy: 0.7718 - val_loss: 0.9683 - val_pothole_loss: 0.3046 - val_pothole_level_loss: 0.6638 - val_pothole_accuracy: 0.8853 - val_pothole_level_accuracy: 0.7682
# Epoch 4/50
# 233/233 [==============================] - 190s 816ms/step - loss: 0.9064 - pothole_loss: 0.2500 - pothole_level_loss: 0.6564 - pothole_accuracy: 0.9108 - pothole_level_accuracy: 0.7890 - val_loss: 0.8202 - val_pothole_loss: 0.2645 - val_pothole_level_loss: 0.5558 - val_pothole_accuracy: 0.8996 - val_pothole_level_accuracy: 0.8187
# Epoch 5/50
# 233/233 [==============================] - 190s 814ms/step - loss: 0.8472 - pothole_loss: 0.2368 - pothole_level_loss: 0.6103 - pothole_accuracy: 0.9124 - pothole_level_accuracy: 0.8008 - val_loss: 1.6001 - val_pothole_loss: 0.7208 - val_pothole_level_loss: 0.8793 - val_pothole_accuracy: 0.7264 - val_pothole_level_accuracy: 0.7682
# Epoch 6/50
# 233/233 [==============================] - 190s 813ms/step - loss: 0.8074 - pothole_loss: 0.2256 - pothole_level_loss: 0.5818 - pothole_accuracy: 0.9168 - pothole_level_accuracy: 0.8134 - val_loss: 1.7618 - val_pothole_loss: 1.2375 - val_pothole_level_loss: 0.5243 - val_pothole_accuracy: 0.4034 - val_pothole_level_accuracy: 0.8432
# Epoch 7/50
# 233/233 [==============================] - 192s 822ms/step - loss: 0.7826 - pothole_loss: 0.2189 - pothole_level_loss: 0.5637 - pothole_accuracy: 0.9176 - pothole_level_accuracy: 0.8208 - val_loss: 4.7950 - val_pothole_loss: 2.9684 - val_pothole_level_loss: 1.8266 - val_pothole_accuracy: 0.2913 - val_pothole_level_accuracy: 0.2477
# Epoch 8/50
# 233/233 [==============================] - 192s 823ms/step - loss: 0.7505 - pothole_loss: 0.2092 - pothole_level_loss: 0.5413 - pothole_accuracy: 0.9215 - pothole_level_accuracy: 0.8263 - val_loss: 1.4166 - val_pothole_loss: 0.6806 - val_pothole_level_loss: 0.7360 - val_pothole_accuracy: 0.6998 - val_pothole_level_accuracy: 0.8037
# Epoch 9/50
# 233/233 [==============================] - 192s 824ms/step - loss: 0.7295 - pothole_loss: 0.1997 - pothole_level_loss: 0.5298 - pothole_accuracy: 0.9251 - pothole_level_accuracy: 0.8299 - val_loss: 0.7875 - val_pothole_loss: 0.2893 - val_pothole_level_loss: 0.4982 - val_pothole_accuracy: 0.8947 - val_pothole_level_accuracy: 0.8450
# Epoch 10/50
# 233/233 [==============================] - 191s 819ms/step - loss: 0.7105 - pothole_loss: 0.1928 - pothole_level_loss: 0.5176 - pothole_accuracy: 0.9267 - pothole_level_accuracy: 0.8328 - val_loss: 0.9084 - val_pothole_loss: 0.3521 - val_pothole_level_loss: 0.5563 - val_pothole_accuracy: 0.8510 - val_pothole_level_accuracy: 0.8458
# Epoch 11/50
# 233/233 [==============================] - 192s 823ms/step - loss: 0.6937 - pothole_loss: 0.1853 - pothole_level_loss: 0.5084 - pothole_accuracy: 0.9308 - pothole_level_accuracy: 0.8386 - val_loss: 1.1141 - val_pothole_loss: 0.3850 - val_pothole_level_loss: 0.7291 - val_pothole_accuracy: 0.8528 - val_pothole_level_accuracy: 0.7476
# Epoch 12/50
# 233/233 [==============================] - 192s 824ms/step - loss: 0.6763 - pothole_loss: 0.1765 - pothole_level_loss: 0.4998 - pothole_accuracy: 0.9319 - pothole_level_accuracy: 0.8423 - val_loss: 5.1703 - val_pothole_loss: 2.6876 - val_pothole_level_loss: 2.4827 - val_pothole_accuracy: 0.3454 - val_pothole_level_accuracy: 0.1784
# Epoch 13/50
# 233/233 [==============================] - 193s 827ms/step - loss: 0.6600 - pothole_loss: 0.1671 - pothole_level_loss: 0.4929 - pothole_accuracy: 0.9367 - pothole_level_accuracy: 0.8436 - val_loss: 2.5810 - val_pothole_loss: 1.2340 - val_pothole_level_loss: 1.3470 - val_pothole_accuracy: 0.5084 - val_pothole_level_accuracy: 0.4300
# Epoch 14/50
# 233/233 [==============================] - 192s 824ms/step - loss: 0.6530 - pothole_loss: 0.1639 - pothole_level_loss: 0.4891 - pothole_accuracy: 0.9372 - pothole_level_accuracy: 0.8470 - val_loss: 1.2020 - val_pothole_loss: 0.4493 - val_pothole_level_loss: 0.7527 - val_pothole_accuracy: 0.7847 - val_pothole_level_accuracy: 0.8169
# Epoch 15/50
# 233/233 [==============================] - 193s 826ms/step - loss: 0.6427 - pothole_loss: 0.1565 - pothole_level_loss: 0.4862 - pothole_accuracy: 0.9415 - pothole_level_accuracy: 0.8493 - val_loss: 0.9296 - val_pothole_loss: 0.3414 - val_pothole_level_loss: 0.5882 - val_pothole_accuracy: 0.8697 - val_pothole_level_accuracy: 0.8106
# Epoch 16/50
# 233/233 [==============================] - 193s 826ms/step - loss: 0.6254 - pothole_loss: 0.1489 - pothole_level_loss: 0.4765 - pothole_accuracy: 0.9441 - pothole_level_accuracy: 0.8504 - val_loss: 1.1409 - val_pothole_loss: 0.2973 - val_pothole_level_loss: 0.8436 - val_pothole_accuracy: 0.8777 - val_pothole_level_accuracy: 0.6996
# Epoch 17/50
# 233/233 [==============================] - 193s 827ms/step - loss: 0.6236 - pothole_loss: 0.1483 - pothole_level_loss: 0.4753 - pothole_accuracy: 0.9436 - pothole_level_accuracy: 0.8488 - val_loss: 0.7368 - val_pothole_loss: 0.2544 - val_pothole_level_loss: 0.4824 - val_pothole_accuracy: 0.9112 - val_pothole_level_accuracy: 0.8432
# Epoch 18/50
# 233/233 [==============================] - 193s 827ms/step - loss: 0.6059 - pothole_loss: 0.1389 - pothole_level_loss: 0.4670 - pothole_accuracy: 0.9467 - pothole_level_accuracy: 0.8549 - val_loss: 0.8747 - val_pothole_loss: 0.3601 - val_pothole_level_loss: 0.5146 - val_pothole_accuracy: 0.8557 - val_pothole_level_accuracy: 0.8504
# Epoch 19/50
# 233/233 [==============================] - 193s 828ms/step - loss: 0.6000 - pothole_loss: 0.1328 - pothole_level_loss: 0.4672 - pothole_accuracy: 0.9504 - pothole_level_accuracy: 0.8551 - val_loss: 0.8374 - val_pothole_loss: 0.3727 - val_pothole_level_loss: 0.4648 - val_pothole_accuracy: 0.8186 - val_pothole_level_accuracy: 0.8536
# Epoch 20/50
# 233/233 [==============================] - 193s 826ms/step - loss: 0.5799 - pothole_loss: 0.1248 - pothole_level_loss: 0.4551 - pothole_accuracy: 0.9538 - pothole_level_accuracy: 0.8560 - val_loss: 1.2692 - val_pothole_loss: 0.5027 - val_pothole_level_loss: 0.7666 - val_pothole_accuracy: 0.8092 - val_pothole_level_accuracy: 0.8031
# Epoch 21/50
# 233/233 [==============================] - 194s 832ms/step - loss: 0.5920 - pothole_loss: 0.1278 - pothole_level_loss: 0.4642 - pothole_accuracy: 0.9528 - pothole_level_accuracy: 0.8551 - val_loss: 0.8210 - val_pothole_loss: 0.2693 - val_pothole_level_loss: 0.5517 - val_pothole_accuracy: 0.9033 - val_pothole_level_accuracy: 0.8377
# Epoch 22/50
# 233/233 [==============================] - 193s 826ms/step - loss: 0.5669 - pothole_loss: 0.1195 - pothole_level_loss: 0.4474 - pothole_accuracy: 0.9556 - pothole_level_accuracy: 0.8572 - val_loss: 0.7745 - val_pothole_loss: 0.3098 - val_pothole_level_loss: 0.4647 - val_pothole_accuracy: 0.8790 - val_pothole_level_accuracy: 0.8584
# Epoch 23/50
# 233/233 [==============================] - 193s 827ms/step - loss: 0.5545 - pothole_loss: 0.1124 - pothole_level_loss: 0.4420 - pothole_accuracy: 0.9586 - pothole_level_accuracy: 0.8590 - val_loss: 0.7456 - val_pothole_loss: 0.2622 - val_pothole_level_loss: 0.4833 - val_pothole_accuracy: 0.9076 - val_pothole_level_accuracy: 0.8447
# Epoch 24/50
# 233/233 [==============================] - 193s 827ms/step - loss: 0.5469 - pothole_loss: 0.1060 - pothole_level_loss: 0.4409 - pothole_accuracy: 0.9617 - pothole_level_accuracy: 0.8564 - val_loss: 2.1390 - val_pothole_loss: 1.0705 - val_pothole_level_loss: 1.0686 - val_pothole_accuracy: 0.6279 - val_pothole_level_accuracy: 0.6228
# Epoch 25/50
# 233/233 [==============================] - 192s 826ms/step - loss: 0.5403 - pothole_loss: 0.1011 - pothole_level_loss: 0.4393 - pothole_accuracy: 0.9646 - pothole_level_accuracy: 0.8593 - val_loss: 0.8963 - val_pothole_loss: 0.3804 - val_pothole_level_loss: 0.5158 - val_pothole_accuracy: 0.8458 - val_pothole_level_accuracy: 0.8291
# Epoch 26/50
# 233/233 [==============================] - 193s 827ms/step - loss: 0.5249 - pothole_loss: 0.0953 - pothole_level_loss: 0.4296 - pothole_accuracy: 0.9659 - pothole_level_accuracy: 0.8615 - val_loss: 0.7852 - val_pothole_loss: 0.3058 - val_pothole_level_loss: 0.4793 - val_pothole_accuracy: 0.8994 - val_pothole_level_accuracy: 0.8487
# Epoch 27/50
# 233/233 [==============================] - 193s 826ms/step - loss: 0.5160 - pothole_loss: 0.0888 - pothole_level_loss: 0.4272 - pothole_accuracy: 0.9709 - pothole_level_accuracy: 0.8626 - val_loss: 0.8002 - val_pothole_loss: 0.2919 - val_pothole_level_loss: 0.5083 - val_pothole_accuracy: 0.9018 - val_pothole_level_accuracy: 0.8246
# Epoch 28/50
# 233/233 [==============================] - 193s 828ms/step - loss: 0.5064 - pothole_loss: 0.0829 - pothole_level_loss: 0.4235 - pothole_accuracy: 0.9726 - pothole_level_accuracy: 0.8618 - val_loss: 0.7769 - val_pothole_loss: 0.3452 - val_pothole_level_loss: 0.4317 - val_pothole_accuracy: 0.8807 - val_pothole_level_accuracy: 0.8618
# Epoch 29/50
# 233/233 [==============================] - 193s 828ms/step - loss: 0.5001 - pothole_loss: 0.0786 - pothole_level_loss: 0.4216 - pothole_accuracy: 0.9758 - pothole_level_accuracy: 0.8628 - val_loss: 0.9860 - val_pothole_loss: 0.3292 - val_pothole_level_loss: 0.6568 - val_pothole_accuracy: 0.8693 - val_pothole_level_accuracy: 0.8062
# Epoch 30/50
# 129/233 [===============>..............] - ETA: 1:13 - loss: 0.4929 - pothole_loss: 0.0738 - pothole_level_loss: 0.4191 - pothole_accuracy: 0.9779 - pothole_level_accuracy: 0.8629

# %%
model.save("pothole_detection_model_prototype_2_sgd.h5")

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

tflite_model_quant = converter.convert()
open("pothole_detection_model_prototype_2_sgd.tflite" , "wb").write(tflite_model_quant)

# %%
# import tensorflow as tf

# model = tf.keras.models.load_model('/content/gdrive/MyDrive/A_I/pothole_detection_model_prototype_1_adam.h5')
# converter = tf.lite.TFLiteConverter.from_keras_model(model)
# tflite_model = converter.convert()
# open("/content/gdrive/MyDrive/A_I/pothole_detection_model_prototype_1_adam.tflite", "wb").write(tflite_model)
