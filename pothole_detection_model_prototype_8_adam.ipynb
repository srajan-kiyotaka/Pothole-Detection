# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !git clone "https://github.com/srajan-kiyotaka/Pothole-Detection.git"
# Out:
# fatal: destination path 'Pothole-Detection' already exists and is not an empty directory.

# %%
# Importing the csv file

import pandas as pd
import numpy as np

features = pd.read_csv(r"/content/Pothole-Detection/Dataset_Info.csv")

features.head(10)
# Out:
#               Image ID  Pothole  Number of Potholes Level  Unnamed: 4
# 0   pothole_image_1299        1                   3     B         NaN
# 1  pothole_image_10064        1                   1     A         NaN
# 2  pothole_image_10079        1                   1     A         NaN
# 3  pothole_image_10084        1                   1     A         NaN
# 4  pothole_image_10087        1                   2     A         NaN
# 5  pothole_image_10110        1                   1     A         NaN
# 6  pothole_image_10119        1                   1     A         NaN
# 7  pothole_image_10120        1                   1     A         NaN
# 8  pothole_image_10135        1                   1     A         NaN
# 9  pothole_image_10139        1                   1     A         NaN

# %%
features.isna().sum()
# Out:
# Image ID                  0
# Pothole                   0
# Number of Potholes        0
# Level                     0
# Unnamed: 4            30000
# dtype: int64

# %%
features = features.drop('Unnamed: 4', axis = 1)

# %%
features.head(10)
# Out:
#               Image ID  Pothole  Number of Potholes Level
# 0   pothole_image_1299        1                   3     B
# 1  pothole_image_10064        1                   1     A
# 2  pothole_image_10079        1                   1     A
# 3  pothole_image_10084        1                   1     A
# 4  pothole_image_10087        1                   2     A
# 5  pothole_image_10110        1                   1     A
# 6  pothole_image_10119        1                   1     A
# 7  pothole_image_10120        1                   1     A
# 8  pothole_image_10135        1                   1     A
# 9  pothole_image_10139        1                   1     A

# %%
features.isna().sum()
# Out:
# Image ID              0
# Pothole               0
# Number of Potholes    0
# Level                 0
# dtype: int64

# %%
all_image_names = features['Image ID']
features = features.drop('Image ID', axis = 1)

pothole_or_not = features['Pothole']
pothole_info = features['Number of Potholes']
pothole_level = features['Level']

pothole_or_not = pd.get_dummies(pothole_or_not, columns = ['Pothole'])
pothole_or_not.columns = ['Normal Road', 'Pothole']
pothole_level = pd.get_dummies(pothole_level, columns = ['Level'])

features = pothole_or_not.join(pothole_info)
features = features.join(pothole_level)

print(features.head(10))
# Out:
#    Normal Road  Pothole  Number of Potholes  A  B  C  S
# 0            0        1                   3  0  1  0  0
# 1            0        1                   1  1  0  0  0
# 2            0        1                   1  1  0  0  0
# 3            0        1                   1  1  0  0  0
# 4            0        1                   2  1  0  0  0
# 5            0        1                   1  1  0  0  0
# 6            0        1                   1  1  0  0  0
# 7            0        1                   1  1  0  0  0
# 8            0        1                   1  1  0  0  0
# 9            0        1                   1  1  0  0  0

# %%
from sklearn.utils import shuffle

image_names_shuffled, labels_shuffled = shuffle(all_image_names, features)

# %%
from sklearn.model_selection import train_test_split

X_train_image_names, X_test_image_names, y_train, y_test = train_test_split(
    image_names_shuffled, labels_shuffled, test_size=0.3, random_state=1)

# %%
type(y_train)
# Out:
# pandas.core.frame.DataFrame

# %%
train_pothole_or_not = y_train[['Normal Road', 'Pothole']]
train_pothole_info = y_train['Number of Potholes']
train_pothole_level = y_train[['A', 'B', 'C', 'S']]

test_pothole_or_not = y_test[['Normal Road', 'Pothole']]
test_pothole_info = y_test['Number of Potholes']
test_pothole_level = y_test[['A', 'B', 'C', 'S']]

# %%
y_train.shape
# Out:
# (21000, 7)

# %%
train_pothole_or_not = np.array(train_pothole_or_not)
train_pothole_info = np.array(train_pothole_info)
train_pothole_level = np.array(train_pothole_level)

test_pothole_or_not = np.array(test_pothole_or_not)
test_pothole_info = np.array(test_pothole_info)
test_pothole_level = np.array(test_pothole_level)

# %%
import cv2

def get_image(file_location):
    img = cv2.imread(file_location)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    # img = img/255
    img = cv2.resize(img,(160, 160))
    return img

# %%
import keras
import numpy as np

class My_Custom_Generator(keras.utils.all_utils.Sequence) :
  
  def __init__(self, image_filenames, pothole, pothole_number, pothole_level, batch_size = 128) :
    self.image_filenames = image_filenames
    self.pothole = pothole
    self.pothole_number = pothole_number
    self.pothole_level = pothole_level
    self.batch_size = batch_size
    
    
  def __len__(self) :
    return (np.ceil(len(self.image_filenames) / float(self.batch_size))).astype(np.int)
  
  
  def __getitem__(self, idx) :
    batch_x = self.image_filenames[idx * self.batch_size : (idx+1) * self.batch_size]
    a = self.pothole[idx * self.batch_size : (idx+1) * self.batch_size]
    # b = self.pothole_number[idx * self.batch_size : (idx+1) * self.batch_size]
    c = self.pothole_level[idx * self.batch_size : (idx+1) * self.batch_size]
    batch_y = [np.array(a), np.array(c)] #, np.array(c)]

    return np.array([
            get_image(f'/content/Pothole-Detection/Unified Dataset/{str(file_name)}.jpg')
               for file_name in batch_x]), batch_y

# %%
batch_size = 75

my_training_batch_generator = My_Custom_Generator(X_train_image_names, train_pothole_or_not, train_pothole_info, train_pothole_level, batch_size)
my_validation_batch_generator = My_Custom_Generator(X_test_image_names, test_pothole_or_not, test_pothole_info, test_pothole_level, batch_size)

# %%
import tensorflow as tf
from keras.models import Sequential, Model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Input, Activation, Add, BatchNormalization, Rescaling

input_ = Input(shape = (160, 160, 3), name = "Input Layer")

rescale = Rescaling(scale=1./255)(input_)

conv_1 = Conv2D(64, kernel_size = (8, 8), name = "conv_1")(rescale)
act_1 = Activation("relu", name = "act_1")(conv_1)
pool_1 = MaxPooling2D(pool_size = (8, 8), strides = (1, 1), padding = "valid", name = "pool_1")(act_1)

conv_2 = Conv2D(48, kernel_size = (4, 4), name = "conv_2")(pool_1)
act_2 = Activation("relu", name = "act_2")(conv_2)
pool_2 = MaxPooling2D(pool_size = (4, 4), strides = (1, 1), padding = "valid", name = "pool_2")(act_2)

conv_3 = Conv2D(30, kernel_size = (2, 2), name = "conv_3")(pool_2)
act_3 = Activation("relu", name = "act_3")(conv_3)
pool_3 = MaxPooling2D(pool_size = (2, 2), name = "pool_3")(act_3)

flat_1 = Flatten(name = "flat_1")(pool_3)

dense_1 = Dense(128, activation = "relu", name = "dense_1")(flat_1)
batch_1 = BatchNormalization(name = "batch_1")(dense_1)
dense_2 = Dense(72, activation = "relu", name = "dense_2")(batch_1)
batch_2 = BatchNormalization(name = "batch_2")(dense_2)
dense_3 = Dense(24, activation = "relu", name = "dense_3")(batch_2)
isPothole = Dense(2, activation = "softmax", name = "pothole")(dense_3)

conv_4 = Conv2D(16, kernel_size = (2, 2), name = "conv_4")(pool_3)
act_4 = Activation("relu", name = "act_4")(conv_4)
pool_4 = MaxPooling2D(pool_size = (2, 2), name = "pool_4")(act_4)

# flat_2 = Flatten(name = "flat_2")(pool_4)

# dense_4 = Dense(128, activation = "relu", name = "dense_4")(flat_2)
# batch_3 = BatchNormalization(name = "batch_3")(dense_4)
# add_1 = Add(name = "add_1")([batch_1, batch_3])

# dense_5 = Dense(64, activation = "relu", name = "dense_5")(add_1)
# batch_4 = BatchNormalization(name = "batch_4")(dense_5)
# pothole_num = Dense(1, activation = "relu", name = "pothole_number")(batch_2)

# conv_5 = Conv2D(16, kernel_size = (8, 8), name = "conv_5")(pool_4)
# act_5 = Activation("relu", name = "act_5")(conv_5)
# pool_5 = MaxPooling2D(pool_size = (4, 4), strides = (1, 1), padding = "valid", name = "pool_5")(act_5)

flat_2 = Flatten(name = "flat_2")(pool_4)

dense_4 = Dense(128, activation = "relu", name = "dense_4")(flat_2)
batch_5 = BatchNormalization(name = "batch_5")(dense_4)
add_2 = Add(name = "add_2")([batch_1, batch_5])
batch_6 = BatchNormalization(name = "batch_6")(add_2)
dense_5 = Dense(80, activation = "relu", name = "dense_5")(batch_6)
drop_2 = Dropout(rate = 0.4, name = "drop_2")(dense_5)
# add_3 = Add(name = "add_3")([batch_7, batch_2])
dense_6 = Dense(60, activation = "relu", name = "dense_6")(drop_2)
batch_7 = BatchNormalization(name = "batch_7")(dense_6)
dense_7 = Dense(45, activation = "relu", name = "dense_7")(batch_7)
drop_3 = Dropout(rate = 0.36, name = "drop_3")(dense_7)
dense_8 = Dense(36, activation = "relu", name = "dense_8")(drop_3)
pothole_level = Dense(4, activation = "softmax", name = "pothole_level")(dense_8)

model = Model(inputs = input_, outputs = [isPothole, pothole_level])

opt = tf.keras.optimizers.SGD(learning_rate = 0.0012)

model.compile(
              loss = {
                  'pothole' : 'categorical_crossentropy',
                #   'pothole_number' : 'categorical_crossentropy'
                  'pothole_level' : 'categorical_crossentropy'
              },
              optimizer = opt,
              metrics = ['accuracy']
)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input Layer (InputLayer)       [(None, 160, 160, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 160, 160, 3)  0           ['Input Layer[0][0]']
#
#  conv_1 (Conv2D)                (None, 153, 153, 64  12352       ['rescaling[0][0]']
#                                 )
#
#  act_1 (Activation)             (None, 153, 153, 64  0           ['conv_1[0][0]']
#                                 )
#
#  pool_1 (MaxPooling2D)          (None, 146, 146, 64  0           ['act_1[0][0]']
#                                 )
#
#  conv_2 (Conv2D)                (None, 143, 143, 48  49200       ['pool_1[0][0]']
#                                 )
#
#  act_2 (Activation)             (None, 143, 143, 48  0           ['conv_2[0][0]']
#                                 )
#
#  pool_2 (MaxPooling2D)          (None, 140, 140, 48  0           ['act_2[0][0]']
#                                 )
#
#  conv_3 (Conv2D)                (None, 139, 139, 30  5790        ['pool_2[0][0]']
#                                 )
#
#  act_3 (Activation)             (None, 139, 139, 30  0           ['conv_3[0][0]']
#                                 )
#
#  pool_3 (MaxPooling2D)          (None, 69, 69, 30)   0           ['act_3[0][0]']
#
#  conv_4 (Conv2D)                (None, 68, 68, 16)   1936        ['pool_3[0][0]']
#
#  act_4 (Activation)             (None, 68, 68, 16)   0           ['conv_4[0][0]']
#
#  pool_4 (MaxPooling2D)          (None, 34, 34, 16)   0           ['act_4[0][0]']
#
#  flat_1 (Flatten)               (None, 142830)       0           ['pool_3[0][0]']
#
#  flat_2 (Flatten)               (None, 18496)        0           ['pool_4[0][0]']
#
#  dense_1 (Dense)                (None, 128)          18282368    ['flat_1[0][0]']
#
#  dense_4 (Dense)                (None, 128)          2367616     ['flat_2[0][0]']
#
#  batch_1 (BatchNormalization)   (None, 128)          512         ['dense_1[0][0]']
#
#  batch_5 (BatchNormalization)   (None, 128)          512         ['dense_4[0][0]']
#
#  add_2 (Add)                    (None, 128)          0           ['batch_1[0][0]',
#                                                                   'batch_5[0][0]']
#
#  batch_6 (BatchNormalization)   (None, 128)          512         ['add_2[0][0]']
#
#  dense_5 (Dense)                (None, 80)           10320       ['batch_6[0][0]']
#
#  drop_2 (Dropout)               (None, 80)           0           ['dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 60)           4860        ['drop_2[0][0]']
#
#  batch_7 (BatchNormalization)   (None, 60)           240         ['dense_6[0][0]']
#
#  dense_2 (Dense)                (None, 72)           9288        ['batch_1[0][0]']
#
#  dense_7 (Dense)                (None, 45)           2745        ['batch_7[0][0]']
#
#  batch_2 (BatchNormalization)   (None, 72)           288         ['dense_2[0][0]']
#
#  drop_3 (Dropout)               (None, 45)           0           ['dense_7[0][0]']
#
#  dense_3 (Dense)                (None, 24)           1752        ['batch_2[0][0]']
#
#  dense_8 (Dense)                (None, 36)           1656        ['drop_3[0][0]']
#
#  pothole (Dense)                (None, 2)            50          ['dense_3[0][0]']
#
#  pothole_level (Dense)          (None, 4)            148         ['dense_8[0][0]']
#
# ==================================================================================================
# Total params: 20,752,145
# Trainable params: 20,751,113
# Non-trainable params: 1,032
# __________________________________________________________________________________________________

# %%
keras.utils.all_utils.plot_model(model, "model.png", show_shapes = True, show_layer_names = True)

# %%
# class Logger(keras.callbacks.Callback):
#   def on_epoch_end(self, epoch, logs=None):
#     pothole_accuracy = logs.get('pothole_accuracy')
#     pothole_number_accuracy = logs.get('pothole_number_accuracy')
#     pothole_level_accuracy = logs.get('pothole_level_accuracy')

#     val_pothole_accuracy = logs.get('val_pothole_accuracy')
#     val_pothole_number_accuracy = logs.get('val_pothole_number_accuracy')
#     val_pothole_level_accuracy = logs.get('val_pothole_level_accuracy')

#     print('='*30, epoch + 1, '='*30)
#     print(f'pothole_accuracy: {pothole_accuracy:.2f}, pothole_number_accuracy: {pothole_number_accuracy:.2f}, pothole_level_accuracy: {pothole_level_accuracy:.2f}')
#     print(f'val_pothole_accuracy: {val_pothole_accuracy:.2f}, val_pothole_number_accuracy: {val_pothole_number_accuracy:.2f}, val_pothole_level_accuracy:{val_pothole_level_accuracy:.2f}')

# %%
_ = model.fit_generator(generator=my_training_batch_generator,
                   steps_per_epoch = int(21000 // batch_size),
                   epochs = 60,
                #    verbose = False,
                   validation_data = my_validation_batch_generator,
                #    callbacks = [
                #                 Logger(),
                #                 keras.callbacks.TensorBoard(log_dir = './logs')
                #                 ],
                   validation_steps = int(9000 // batch_size))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# Epoch 1/60
# 280/280 [==============================] - 141s 460ms/step - loss: 1.1771 - pothole_loss: 0.3357 - pothole_level_loss: 0.8414 - pothole_accuracy: 0.8720 - pothole_level_accuracy: 0.7136 - val_loss: 1.5026 - val_pothole_loss: 0.5439 - val_pothole_level_loss: 0.9586 - val_pothole_accuracy: 0.7529 - val_pothole_level_accuracy: 0.7787
# Epoch 2/60
# 280/280 [==============================] - 130s 464ms/step - loss: 0.9379 - pothole_loss: 0.2703 - pothole_level_loss: 0.6676 - pothole_accuracy: 0.9032 - pothole_level_accuracy: 0.7782 - val_loss: 1.2982 - val_pothole_loss: 0.6424 - val_pothole_level_loss: 0.6558 - val_pothole_accuracy: 0.6701 - val_pothole_level_accuracy: 0.8201
# Epoch 3/60
# 280/280 [==============================] - 130s 464ms/step - loss: 0.8752 - pothole_loss: 0.2507 - pothole_level_loss: 0.6245 - pothole_accuracy: 0.9102 - pothole_level_accuracy: 0.7935 - val_loss: 1.3626 - val_pothole_loss: 0.7536 - val_pothole_level_loss: 0.6090 - val_pothole_accuracy: 0.6580 - val_pothole_level_accuracy: 0.8346
# Epoch 4/60
# 280/280 [==============================] - 130s 463ms/step - loss: 0.8220 - pothole_loss: 0.2300 - pothole_level_loss: 0.5920 - pothole_accuracy: 0.9174 - pothole_level_accuracy: 0.7998 - val_loss: 0.9065 - val_pothole_loss: 0.3378 - val_pothole_level_loss: 0.5686 - val_pothole_accuracy: 0.8770 - val_pothole_level_accuracy: 0.8474
# Epoch 5/60
# 280/280 [==============================] - 130s 464ms/step - loss: 0.7879 - pothole_loss: 0.2173 - pothole_level_loss: 0.5705 - pothole_accuracy: 0.9216 - pothole_level_accuracy: 0.8093 - val_loss: 0.7531 - val_pothole_loss: 0.2572 - val_pothole_level_loss: 0.4959 - val_pothole_accuracy: 0.9072 - val_pothole_level_accuracy: 0.8492
# Epoch 6/60
# 280/280 [==============================] - 130s 464ms/step - loss: 0.7623 - pothole_loss: 0.2051 - pothole_level_loss: 0.5572 - pothole_accuracy: 0.9235 - pothole_level_accuracy: 0.8166 - val_loss: 1.0798 - val_pothole_loss: 0.4408 - val_pothole_level_loss: 0.6390 - val_pothole_accuracy: 0.7903 - val_pothole_level_accuracy: 0.8059
# Epoch 7/60
# Epoch 55/60
# 280/280 [==============================] - 130s 464ms/step - loss: 0.2727 - pothole_loss: 0.0191 - pothole_level_loss: 0.2536 - pothole_accuracy: 0.9973 - pothole_level_accuracy: 0.9007 - val_loss: 0.9101 - val_pothole_loss: 0.3348 - val_pothole_level_loss: 0.5752 - val_pothole_accuracy: 0.8882 - val_pothole_level_accuracy: 0.8044
# Epoch 56/60
# 280/280 [==============================] - 130s 464ms/step - loss: 0.2644 - pothole_loss: 0.0173 - pothole_level_loss: 0.2471 - pothole_accuracy: 0.9977 - pothole_level_accuracy: 0.9027 - val_loss: 0.8778 - val_pothole_loss: 0.4098 - val_pothole_level_loss: 0.4680 - val_pothole_accuracy: 0.9101 - val_pothole_level_accuracy: 0.8529
# Epoch 57/60
# 280/280 [==============================] - 130s 464ms/step - loss: 0.2597 - pothole_loss: 0.0152 - pothole_level_loss: 0.2445 - pothole_accuracy: 0.9985 - pothole_level_accuracy: 0.9041 - val_loss: 0.8778 - val_pothole_loss: 0.3356 - val_pothole_level_loss: 0.5422 - val_pothole_accuracy: 0.9163 - val_pothole_level_accuracy: 0.8720
# Epoch 58/60
# 280/280 [==============================] - 130s 465ms/step - loss: 0.2489 - pothole_loss: 0.0136 - pothole_level_loss: 0.2353 - pothole_accuracy: 0.9988 - pothole_level_accuracy: 0.9056 - val_loss: 1.4725 - val_pothole_loss: 0.6788 - val_pothole_level_loss: 0.7937 - val_pothole_accuracy: 0.7827 - val_pothole_level_accuracy: 0.8093
# Epoch 59/60
# 280/280 [==============================] - 130s 464ms/step - loss: 0.2446 - pothole_loss: 0.0123 - pothole_level_loss: 0.2323 - pothole_accuracy: 0.9987 - pothole_level_accuracy: 0.9091 - val_loss: 1.1123 - val_pothole_loss: 0.3928 - val_pothole_level_loss: 0.7194 - val_pothole_accuracy: 0.8891 - val_pothole_level_accuracy: 0.7631
# Epoch 60/60
# 280/280 [==============================] - 130s 465ms/step - loss: 0.2438 - pothole_loss: 0.0128 - pothole_level_loss: 0.2310 - pothole_accuracy: 0.9985 - pothole_level_accuracy: 0.9110 - val_loss: 0.8646 - val_pothole_loss: 0.3626 - val_pothole_level_loss: 0.5020 - val_pothole_accuracy: 0.9157 - val_pothole_level_accuracy: 0.8662

# %%
# model.save(r"/content/gdrive/MyDrive/pothole_detection_model_prototype_8_adam.h5")

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
# converter.optimizations = [tf.lite.Optimize.DEFAULT]

tflite_model_quant = converter.convert()
open(r"/content/gdrive/MyDrive/pothole_detection_model_prototype_8_adam_lite.tflite" , "wb").write(tflite_model_quant)
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input Layer with unsupported characters which will be renamed to placeholder in the SavedModel.
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 83011772

# %%
# import tensorflow as tf

# model = tf.keras.models.load_model('/content/gdrive/MyDrive/A_I/pothole_detection_model_prototype_1_adam.h5')
# converter = tf.lite.TFLiteConverter.from_keras_model(model)
# tflite_model = converter.convert()
# open("/content/gdrive/MyDrive/A_I/pothole_detection_model_prototype_1_adam.tflite", "wb").write(tflite_model)
