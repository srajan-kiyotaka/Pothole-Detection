# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone "https://github.com/srajan-kiyotaka/Pothole-Detection.git"
# Out:
# Cloning into 'Pothole-Detection'...
# remote: Enumerating objects: 29926, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 29926 (delta 7), reused 22 (delta 4), pack-reused 29893
# Receiving objects: 100% (29926/29926), 1.14 GiB | 47.67 MiB/s, done.
# Resolving deltas: 100% (1426/1426), done.
# Checking out files: 100% (30004/30004), done.

# %%
# Importing the csv file

import pandas as pd
import numpy as np

features = pd.read_csv(r"/content/Pothole-Detection/Dataset_Info.csv")

features.head(10)
# Out:
#               Image ID  Pothole  Number of Potholes Level  Unnamed: 4
# 0   pothole_image_1299        1                   3     B         NaN
# 1  pothole_image_10064        1                   1     A         NaN
# 2  pothole_image_10079        1                   1     A         NaN
# 3  pothole_image_10084        1                   1     A         NaN
# 4  pothole_image_10087        1                   2     A         NaN
# 5  pothole_image_10110        1                   1     A         NaN
# 6  pothole_image_10119        1                   1     A         NaN
# 7  pothole_image_10120        1                   1     A         NaN
# 8  pothole_image_10135        1                   1     A         NaN
# 9  pothole_image_10139        1                   1     A         NaN

# %%
features.isna().sum()
# Out:
# Image ID                  0
# Pothole                   0
# Number of Potholes        0
# Level                     0
# Unnamed: 4            30000
# dtype: int64

# %%
features = features.drop('Unnamed: 4', axis = 1)

# %%
features.head(10)
# Out:
#               Image ID  Pothole  Number of Potholes Level
# 0   pothole_image_1299        1                   3     B
# 1  pothole_image_10064        1                   1     A
# 2  pothole_image_10079        1                   1     A
# 3  pothole_image_10084        1                   1     A
# 4  pothole_image_10087        1                   2     A
# 5  pothole_image_10110        1                   1     A
# 6  pothole_image_10119        1                   1     A
# 7  pothole_image_10120        1                   1     A
# 8  pothole_image_10135        1                   1     A
# 9  pothole_image_10139        1                   1     A

# %%
features.isna().sum()
# Out:
# Image ID              0
# Pothole               0
# Number of Potholes    0
# Level                 0
# dtype: int64

# %%
all_image_names = features['Image ID']
features = features.drop('Image ID', axis = 1)

pothole_or_not = features['Pothole']
pothole_info = features['Number of Potholes']
pothole_level = features['Level']

pothole_or_not = pd.get_dummies(pothole_or_not, columns = ['Pothole'])
pothole_or_not.columns = ['Normal Road', 'Pothole']
pothole_level = pd.get_dummies(pothole_level, columns = ['Level'])

features = pothole_or_not.join(pothole_info)
features = features.join(pothole_level)

print(features.head(10))
# Out:
#    Normal Road  Pothole  Number of Potholes  A  B  C  S
# 0            0        1                   3  0  1  0  0
# 1            0        1                   1  1  0  0  0
# 2            0        1                   1  1  0  0  0
# 3            0        1                   1  1  0  0  0
# 4            0        1                   2  1  0  0  0
# 5            0        1                   1  1  0  0  0
# 6            0        1                   1  1  0  0  0
# 7            0        1                   1  1  0  0  0
# 8            0        1                   1  1  0  0  0
# 9            0        1                   1  1  0  0  0

# %%
from sklearn.utils import shuffle

image_names_shuffled, labels_shuffled = shuffle(all_image_names, features)

# %%
from sklearn.model_selection import train_test_split

X_train_image_names, X_test_image_names, y_train, y_test = train_test_split(
    image_names_shuffled, labels_shuffled, test_size=0.3, random_state=1)

# %%
type(y_train)
# Out:
# pandas.core.frame.DataFrame

# %%
train_pothole_or_not = y_train[['Normal Road', 'Pothole']]
train_pothole_info = y_train['Number of Potholes']
train_pothole_level = y_train[['A', 'B', 'C', 'S']]

test_pothole_or_not = y_test[['Normal Road', 'Pothole']]
test_pothole_info = y_test['Number of Potholes']
test_pothole_level = y_test[['A', 'B', 'C', 'S']]

# %%
y_train.shape
# Out:
# (21000, 7)

# %%
train_pothole_or_not = np.array(train_pothole_or_not)
train_pothole_info = np.array(train_pothole_info)
train_pothole_level = np.array(train_pothole_level)

test_pothole_or_not = np.array(test_pothole_or_not)
test_pothole_info = np.array(test_pothole_info)
test_pothole_level = np.array(test_pothole_level)

# %%
import cv2

def get_image(file_location):
    img = cv2.imread(file_location)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    img = img/255
    img = cv2.resize(img,(200, 200))
    return img

# %%
import keras
import numpy as np

class My_Custom_Generator(keras.utils.all_utils.Sequence) :
  
  def __init__(self, image_filenames, pothole, pothole_number, pothole_level, batch_size = 128) :
    self.image_filenames = image_filenames
    self.pothole = pothole
    self.pothole_number = pothole_number
    self.pothole_level = pothole_level
    self.batch_size = batch_size
    
    
  def __len__(self) :
    return (np.ceil(len(self.image_filenames) / float(self.batch_size))).astype(np.int)
  
  
  def __getitem__(self, idx) :
    batch_x = self.image_filenames[idx * self.batch_size : (idx+1) * self.batch_size]
    a = self.pothole[idx * self.batch_size : (idx+1) * self.batch_size]
    # b = self.pothole_number[idx * self.batch_size : (idx+1) * self.batch_size]
    c = self.pothole_level[idx * self.batch_size : (idx+1) * self.batch_size]
    batch_y = [np.array(a), np.array(c)] #, np.array(c)]

    return np.array([
            get_image(f'/content/Pothole-Detection/Unified Dataset/{str(file_name)}.jpg')
               for file_name in batch_x]), batch_y

# %%
batch_size = 100

my_training_batch_generator = My_Custom_Generator(X_train_image_names, train_pothole_or_not, train_pothole_info, train_pothole_level, batch_size)
my_validation_batch_generator = My_Custom_Generator(X_test_image_names, test_pothole_or_not, test_pothole_info, test_pothole_level, batch_size)

# %%
import tensorflow as tf
from keras.models import Sequential, Model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Input, Activation, Add, BatchNormalization

input_ = Input(shape = (200, 200, 1), name = "Input Layer")

conv_1 = Conv2D(64, kernel_size = (4, 4), name = "conv_1")(input_)
act_1 = Activation("relu", name = "act_1")(conv_1)
pool_1 = MaxPooling2D(pool_size = (8, 8), strides = (1, 1), padding = "valid", name = "pool_1")(act_1)

conv_2 = Conv2D(32, kernel_size = (8, 8), name = "conv_2")(pool_1)
act_2 = Activation("relu", name = "act_2")(conv_2)
pool_2 = MaxPooling2D(pool_size = (4, 4), strides = (1, 1), padding = "valid", name = "pool_2")(act_2)

conv_3 = Conv2D(16, kernel_size = (4, 4), name = "conv_3")(pool_2)
act_3 = Activation("relu", name = "act_3")(conv_3)
pool_3 = MaxPooling2D(pool_size = (8, 8), strides = (1, 1), padding = "valid", name = "pool_3")(act_3)

flat_1 = Flatten(name = "flat_1")(pool_3)

dense_1 = Dense(128, activation = "relu", name = "dense_1")(flat_1) 
batch_1 = BatchNormalization(name = "batch_1")(dense_1)
dense_2 = Dense(32, activation = "relu", name = "dense_2")(batch_1)
batch_2 = BatchNormalization(name = "batch_2")(dense_2)
dense_3 = Dense(8, activation = "relu", name = "dense_3")(batch_2)
isPothole = Dense(2, activation = "softmax", name = "pothole")(dense_3)

conv_4 = Conv2D(8, kernel_size = (4, 4), name = "conv_4")(pool_3)
act_4 = Activation("relu", name = "act_4")(conv_4)
pool_4 = MaxPooling2D(pool_size = (8, 8), strides = (1, 1), padding = "valid", name = "pool_4")(act_4)

# flat_2 = Flatten(name = "flat_2")(pool_4)

# dense_4 = Dense(128, activation = "relu", name = "dense_4")(flat_2)
# batch_3 = BatchNormalization(name = "batch_3")(dense_4)
# add_1 = Add(name = "add_1")([batch_1, batch_3])

# dense_5 = Dense(64, activation = "relu", name = "dense_5")(add_1)
# batch_4 = BatchNormalization(name = "batch_4")(dense_5)
# pothole_num = Dense(1, activation = "relu", name = "pothole_number")(batch_2)

# conv_5 = Conv2D(16, kernel_size = (8, 8), name = "conv_5")(pool_4)
# act_5 = Activation("relu", name = "act_5")(conv_5)
# pool_5 = MaxPooling2D(pool_size = (4, 4), strides = (1, 1), padding = "valid", name = "pool_5")(act_5)

flat_2 = Flatten(name = "flat_2")(pool_4)

dense_4 = Dense(128, activation = "relu", name = "dense_4")(flat_2)
batch_5 = BatchNormalization(name = "batch_5")(dense_4)
add_2 = Add(name = "add_2")([batch_1, batch_5])
batch_6 = BatchNormalization(name = "batch_6")(add_2)
dense_5 = Dense(64, activation = "relu", name = "dense_5")(batch_6)
drop_2 = Dropout(rate = 0.4, name = "drop_2")(dense_5)
# add_3 = Add(name = "add_3")([batch_7, batch_2])
dense_6 = Dense(32, activation = "relu", name = "dense_6")(drop_2)
batch_7 = BatchNormalization(name = "batch_7")(dense_6)
dense_7 = Dense(16, activation = "relu", name = "dense_7")(batch_7)
drop_3 = Dropout(rate = 0.4, name = "drop_3")(dense_7)
dense_8 = Dense(8, activation = "relu", name = "dense_8")(drop_3)
pothole_level = Dense(4, activation = "softmax", name = "pothole_level")(dense_8)

model = Model(inputs = input_, outputs = [isPothole, pothole_level])

opt = tf.keras.optimizers.Adam(learning_rate = 0.001)

model.compile(
              loss = {
                  'pothole' : 'binary_crossentropy',
                #   'pothole_number' : 'categorical_crossentropy'
                  'pothole_level' : 'categorical_crossentropy'
              },
              optimizer = opt,
              metrics = ['accuracy']
)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input Layer (InputLayer)       [(None, 200, 200, 1  0           []
#                                 )]
#
#  conv_1 (Conv2D)                (None, 197, 197, 64  1088        ['Input Layer[0][0]']
#                                 )
#
#  act_1 (Activation)             (None, 197, 197, 64  0           ['conv_1[0][0]']
#                                 )
#
#  pool_1 (MaxPooling2D)          (None, 190, 190, 64  0           ['act_1[0][0]']
#                                 )
#
#  conv_2 (Conv2D)                (None, 183, 183, 32  131104      ['pool_1[0][0]']
#                                 )
#
#  act_2 (Activation)             (None, 183, 183, 32  0           ['conv_2[0][0]']
#                                 )
#
#  pool_2 (MaxPooling2D)          (None, 180, 180, 32  0           ['act_2[0][0]']
#                                 )
#
#  conv_3 (Conv2D)                (None, 177, 177, 16  8208        ['pool_2[0][0]']
#                                 )
#
#  act_3 (Activation)             (None, 177, 177, 16  0           ['conv_3[0][0]']
#                                 )
#
#  pool_3 (MaxPooling2D)          (None, 170, 170, 16  0           ['act_3[0][0]']
#                                 )
#
#  conv_4 (Conv2D)                (None, 167, 167, 8)  2056        ['pool_3[0][0]']
#
#  act_4 (Activation)             (None, 167, 167, 8)  0           ['conv_4[0][0]']
#
#  pool_4 (MaxPooling2D)          (None, 160, 160, 8)  0           ['act_4[0][0]']
#
#  flat_1 (Flatten)               (None, 462400)       0           ['pool_3[0][0]']
#
#  flat_2 (Flatten)               (None, 204800)       0           ['pool_4[0][0]']
#
#  dense_1 (Dense)                (None, 128)          59187328    ['flat_1[0][0]']
#
#  dense_4 (Dense)                (None, 128)          26214528    ['flat_2[0][0]']
#
#  batch_1 (BatchNormalization)   (None, 128)          512         ['dense_1[0][0]']
#
#  batch_5 (BatchNormalization)   (None, 128)          512         ['dense_4[0][0]']
#
#  add_2 (Add)                    (None, 128)          0           ['batch_1[0][0]',
#                                                                   'batch_5[0][0]']
#
#  batch_6 (BatchNormalization)   (None, 128)          512         ['add_2[0][0]']
#
#  dense_5 (Dense)                (None, 64)           8256        ['batch_6[0][0]']
#
#  drop_2 (Dropout)               (None, 64)           0           ['dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 32)           2080        ['drop_2[0][0]']
#
#  batch_7 (BatchNormalization)   (None, 32)           128         ['dense_6[0][0]']
#
#  dense_2 (Dense)                (None, 32)           4128        ['batch_1[0][0]']
#
#  dense_7 (Dense)                (None, 16)           528         ['batch_7[0][0]']
#
#  batch_2 (BatchNormalization)   (None, 32)           128         ['dense_2[0][0]']
#
#  drop_3 (Dropout)               (None, 16)           0           ['dense_7[0][0]']
#
#  dense_3 (Dense)                (None, 8)            264         ['batch_2[0][0]']
#
#  dense_8 (Dense)                (None, 8)            136         ['drop_3[0][0]']
#
#  pothole (Dense)                (None, 2)            18          ['dense_3[0][0]']
#
#  pothole_level (Dense)          (None, 4)            36          ['dense_8[0][0]']
#
# ==================================================================================================
# Total params: 85,561,550
# Trainable params: 85,560,654
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
keras.utils.all_utils.plot_model(model, "model.png", show_shapes = True, show_layer_names = True)

# %%
# class Logger(keras.callbacks.Callback):
#   def on_epoch_end(self, epoch, logs=None):
#     pothole_accuracy = logs.get('pothole_accuracy')
#     pothole_number_accuracy = logs.get('pothole_number_accuracy')
#     pothole_level_accuracy = logs.get('pothole_level_accuracy')

#     val_pothole_accuracy = logs.get('val_pothole_accuracy')
#     val_pothole_number_accuracy = logs.get('val_pothole_number_accuracy')
#     val_pothole_level_accuracy = logs.get('val_pothole_level_accuracy')

#     print('='*30, epoch + 1, '='*30)
#     print(f'pothole_accuracy: {pothole_accuracy:.2f}, pothole_number_accuracy: {pothole_number_accuracy:.2f}, pothole_level_accuracy: {pothole_level_accuracy:.2f}')
#     print(f'val_pothole_accuracy: {val_pothole_accuracy:.2f}, val_pothole_number_accuracy: {val_pothole_number_accuracy:.2f}, val_pothole_level_accuracy:{val_pothole_level_accuracy:.2f}')

# %%
_ = model.fit_generator(generator=my_training_batch_generator,
                   steps_per_epoch = int(21000 // batch_size),
                   epochs = 50,
                #    verbose = False,
                   validation_data = my_validation_batch_generator,
                #    callbacks = [
                #                 Logger(),
                #                 keras.callbacks.TensorBoard(log_dir = './logs')
                #                 ],
                   validation_steps = int(9000 // batch_size))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# Epoch 1/50
# 210/210 [==============================] - 264s 1s/step - loss: 1.2382 - pothole_loss: 0.3954 - pothole_level_loss: 0.8428 - pothole_accuracy: 0.8470 - pothole_level_accuracy: 0.7058 - val_loss: 0.9271 - val_pothole_loss: 0.3154 - val_pothole_level_loss: 0.6117 - val_pothole_accuracy: 0.8812 - val_pothole_level_accuracy: 0.7786
# Epoch 2/50
# 210/210 [==============================] - 239s 1s/step - loss: 0.9070 - pothole_loss: 0.2921 - pothole_level_loss: 0.6149 - pothole_accuracy: 0.8950 - pothole_level_accuracy: 0.7880 - val_loss: 0.9700 - val_pothole_loss: 0.4002 - val_pothole_level_loss: 0.5698 - val_pothole_accuracy: 0.8832 - val_pothole_level_accuracy: 0.8176
# Epoch 3/50
# 210/210 [==============================] - 237s 1s/step - loss: 0.8170 - pothole_loss: 0.2637 - pothole_level_loss: 0.5533 - pothole_accuracy: 0.9065 - pothole_level_accuracy: 0.8155 - val_loss: 0.9262 - val_pothole_loss: 0.3031 - val_pothole_level_loss: 0.6231 - val_pothole_accuracy: 0.8974 - val_pothole_level_accuracy: 0.7967
# Epoch 4/50
# 210/210 [==============================] - 237s 1s/step - loss: 0.7788 - pothole_loss: 0.2547 - pothole_level_loss: 0.5240 - pothole_accuracy: 0.9066 - pothole_level_accuracy: 0.8314 - val_loss: 1.0781 - val_pothole_loss: 0.4354 - val_pothole_level_loss: 0.6427 - val_pothole_accuracy: 0.8814 - val_pothole_level_accuracy: 0.7569
# Epoch 5/50
# 210/210 [==============================] - 235s 1s/step - loss: 0.7333 - pothole_loss: 0.2376 - pothole_level_loss: 0.4957 - pothole_accuracy: 0.9137 - pothole_level_accuracy: 0.8399 - val_loss: 1.4619 - val_pothole_loss: 0.6404 - val_pothole_level_loss: 0.8214 - val_pothole_accuracy: 0.7379 - val_pothole_level_accuracy: 0.7813
# Epoch 6/50
# 210/210 [==============================] - 235s 1s/step - loss: 0.6986 - pothole_loss: 0.2237 - pothole_level_loss: 0.4749 - pothole_accuracy: 0.9167 - pothole_level_accuracy: 0.8465 - val_loss: 1.1223 - val_pothole_loss: 0.5824 - val_pothole_level_loss: 0.5399 - val_pothole_accuracy: 0.8034 - val_pothole_level_accuracy: 0.8482
# Epoch 7/50
# 210/210 [==============================] - 234s 1s/step - loss: 0.6796 - pothole_loss: 0.2142 - pothole_level_loss: 0.4654 - pothole_accuracy: 0.9203 - pothole_level_accuracy: 0.8517 - val_loss: 4.5222 - val_pothole_loss: 1.9770 - val_pothole_level_loss: 2.5452 - val_pothole_accuracy: 0.7286 - val_pothole_level_accuracy: 0.7777
# Epoch 8/50
# 210/210 [==============================] - 233s 1s/step - loss: 0.6631 - pothole_loss: 0.2061 - pothole_level_loss: 0.4570 - pothole_accuracy: 0.9220 - pothole_level_accuracy: 0.8557 - val_loss: 0.7839 - val_pothole_loss: 0.3165 - val_pothole_level_loss: 0.4674 - val_pothole_accuracy: 0.8912 - val_pothole_level_accuracy: 0.8547
# Epoch 9/50
# 210/210 [==============================] - 234s 1s/step - loss: 0.6418 - pothole_loss: 0.1966 - pothole_level_loss: 0.4452 - pothole_accuracy: 0.9255 - pothole_level_accuracy: 0.8592 - val_loss: 1.5537 - val_pothole_loss: 0.4472 - val_pothole_level_loss: 1.1064 - val_pothole_accuracy: 0.8180 - val_pothole_level_accuracy: 0.5936
# Epoch 10/50
# 210/210 [==============================] - 232s 1s/step - loss: 0.6248 - pothole_loss: 0.1878 - pothole_level_loss: 0.4370 - pothole_accuracy: 0.9297 - pothole_level_accuracy: 0.8615 - val_loss: 1.2976 - val_pothole_loss: 0.4306 - val_pothole_level_loss: 0.8671 - val_pothole_accuracy: 0.8276 - val_pothole_level_accuracy: 0.6724
# Epoch 11/50
# 210/210 [==============================] - 231s 1s/step - loss: 0.6179 - pothole_loss: 0.1838 - pothole_level_loss: 0.4341 - pothole_accuracy: 0.9303 - pothole_level_accuracy: 0.8616 - val_loss: 2.0297 - val_pothole_loss: 0.7282 - val_pothole_level_loss: 1.3015 - val_pothole_accuracy: 0.8242 - val_pothole_level_accuracy: 0.5757
# Epoch 12/50
# 210/210 [==============================] - 230s 1s/step - loss: 0.6024 - pothole_loss: 0.1719 - pothole_level_loss: 0.4304 - pothole_accuracy: 0.9338 - pothole_level_accuracy: 0.8627 - val_loss: 2.1007 - val_pothole_loss: 0.3869 - val_pothole_level_loss: 1.7138 - val_pothole_accuracy: 0.8616 - val_pothole_level_accuracy: 0.7778
# Epoch 13/50
# 210/210 [==============================] - 231s 1s/step - loss: 0.5754 - pothole_loss: 0.1594 - pothole_level_loss: 0.4160 - pothole_accuracy: 0.9390 - pothole_level_accuracy: 0.8646 - val_loss: 0.9766 - val_pothole_loss: 0.3947 - val_pothole_level_loss: 0.5819 - val_pothole_accuracy: 0.8784 - val_pothole_level_accuracy: 0.8554
# Epoch 14/50
# 210/210 [==============================] - 232s 1s/step - loss: 0.5525 - pothole_loss: 0.1468 - pothole_level_loss: 0.4057 - pothole_accuracy: 0.9414 - pothole_level_accuracy: 0.8668 - val_loss: 1.1421 - val_pothole_loss: 0.5340 - val_pothole_level_loss: 0.6081 - val_pothole_accuracy: 0.8653 - val_pothole_level_accuracy: 0.8317
# Epoch 15/50
# 210/210 [==============================] - 231s 1s/step - loss: 0.5642 - pothole_loss: 0.1543 - pothole_level_loss: 0.4099 - pothole_accuracy: 0.9418 - pothole_level_accuracy: 0.8660 - val_loss: 3.9366 - val_pothole_loss: 1.2028 - val_pothole_level_loss: 2.7338 - val_pothole_accuracy: 0.5960 - val_pothole_level_accuracy: 0.2232
# Epoch 16/50
# 210/210 [==============================] - 230s 1s/step - loss: 0.5383 - pothole_loss: 0.1412 - pothole_level_loss: 0.3971 - pothole_accuracy: 0.9446 - pothole_level_accuracy: 0.8682 - val_loss: 1.0075 - val_pothole_loss: 0.5410 - val_pothole_level_loss: 0.4665 - val_pothole_accuracy: 0.8197 - val_pothole_level_accuracy: 0.8548
# Epoch 17/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.5038 - pothole_loss: 0.1194 - pothole_level_loss: 0.3844 - pothole_accuracy: 0.9535 - pothole_level_accuracy: 0.8705 - val_loss: 0.9168 - val_pothole_loss: 0.4363 - val_pothole_level_loss: 0.4805 - val_pothole_accuracy: 0.9100 - val_pothole_level_accuracy: 0.8612
# Epoch 18/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.4878 - pothole_loss: 0.1077 - pothole_level_loss: 0.3800 - pothole_accuracy: 0.9571 - pothole_level_accuracy: 0.8708 - val_loss: 1.3089 - val_pothole_loss: 0.4256 - val_pothole_level_loss: 0.8833 - val_pothole_accuracy: 0.8673 - val_pothole_level_accuracy: 0.7341
# Epoch 19/50
# 210/210 [==============================] - 230s 1s/step - loss: 0.4664 - pothole_loss: 0.0960 - pothole_level_loss: 0.3704 - pothole_accuracy: 0.9612 - pothole_level_accuracy: 0.8718 - val_loss: 0.8771 - val_pothole_loss: 0.4123 - val_pothole_level_loss: 0.4648 - val_pothole_accuracy: 0.8450 - val_pothole_level_accuracy: 0.8577
# Epoch 20/50
# 210/210 [==============================] - 230s 1s/step - loss: 0.4425 - pothole_loss: 0.0816 - pothole_level_loss: 0.3609 - pothole_accuracy: 0.9681 - pothole_level_accuracy: 0.8734 - val_loss: 0.9608 - val_pothole_loss: 0.4535 - val_pothole_level_loss: 0.5073 - val_pothole_accuracy: 0.8817 - val_pothole_level_accuracy: 0.8558
# Epoch 21/50
# 210/210 [==============================] - 230s 1s/step - loss: 0.4290 - pothole_loss: 0.0763 - pothole_level_loss: 0.3527 - pothole_accuracy: 0.9703 - pothole_level_accuracy: 0.8739 - val_loss: 0.9008 - val_pothole_loss: 0.4248 - val_pothole_level_loss: 0.4760 - val_pothole_accuracy: 0.8908 - val_pothole_level_accuracy: 0.8591
# Epoch 22/50
# 210/210 [==============================] - 230s 1s/step - loss: 0.4060 - pothole_loss: 0.0647 - pothole_level_loss: 0.3413 - pothole_accuracy: 0.9759 - pothole_level_accuracy: 0.8757 - val_loss: 1.3825 - val_pothole_loss: 0.6132 - val_pothole_level_loss: 0.7694 - val_pothole_accuracy: 0.8720 - val_pothole_level_accuracy: 0.8431
# Epoch 23/50
# 210/210 [==============================] - 230s 1s/step - loss: 0.3975 - pothole_loss: 0.0609 - pothole_level_loss: 0.3366 - pothole_accuracy: 0.9773 - pothole_level_accuracy: 0.8762 - val_loss: 0.9913 - val_pothole_loss: 0.4853 - val_pothole_level_loss: 0.5060 - val_pothole_accuracy: 0.8594 - val_pothole_level_accuracy: 0.8498
# Epoch 24/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.3777 - pothole_loss: 0.0497 - pothole_level_loss: 0.3280 - pothole_accuracy: 0.9825 - pothole_level_accuracy: 0.8773 - val_loss: 1.7511 - val_pothole_loss: 0.8419 - val_pothole_level_loss: 0.9092 - val_pothole_accuracy: 0.8704 - val_pothole_level_accuracy: 0.8600
# Epoch 25/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.3788 - pothole_loss: 0.0514 - pothole_level_loss: 0.3273 - pothole_accuracy: 0.9817 - pothole_level_accuracy: 0.8761 - val_loss: 1.2124 - val_pothole_loss: 0.5575 - val_pothole_level_loss: 0.6549 - val_pothole_accuracy: 0.8380 - val_pothole_level_accuracy: 0.7940
# Epoch 26/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.3490 - pothole_loss: 0.0388 - pothole_level_loss: 0.3103 - pothole_accuracy: 0.9864 - pothole_level_accuracy: 0.8807 - val_loss: 2.0828 - val_pothole_loss: 0.9620 - val_pothole_level_loss: 1.1208 - val_pothole_accuracy: 0.7711 - val_pothole_level_accuracy: 0.7910
# Epoch 27/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.3418 - pothole_loss: 0.0378 - pothole_level_loss: 0.3040 - pothole_accuracy: 0.9866 - pothole_level_accuracy: 0.8801 - val_loss: 1.2600 - val_pothole_loss: 0.6154 - val_pothole_level_loss: 0.6446 - val_pothole_accuracy: 0.8904 - val_pothole_level_accuracy: 0.8633
# Epoch 28/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.3315 - pothole_loss: 0.0358 - pothole_level_loss: 0.2957 - pothole_accuracy: 0.9873 - pothole_level_accuracy: 0.8825 - val_loss: 1.5417 - val_pothole_loss: 0.6723 - val_pothole_level_loss: 0.8694 - val_pothole_accuracy: 0.8951 - val_pothole_level_accuracy: 0.8421
# Epoch 29/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.3251 - pothole_loss: 0.0339 - pothole_level_loss: 0.2912 - pothole_accuracy: 0.9877 - pothole_level_accuracy: 0.8833 - val_loss: 2.1314 - val_pothole_loss: 1.0974 - val_pothole_level_loss: 1.0340 - val_pothole_accuracy: 0.8058 - val_pothole_level_accuracy: 0.8171
# Epoch 30/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.3101 - pothole_loss: 0.0263 - pothole_level_loss: 0.2838 - pothole_accuracy: 0.9908 - pothole_level_accuracy: 0.8855 - val_loss: 1.5598 - val_pothole_loss: 0.6207 - val_pothole_level_loss: 0.9391 - val_pothole_accuracy: 0.8940 - val_pothole_level_accuracy: 0.7394
# Epoch 31/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.2954 - pothole_loss: 0.0207 - pothole_level_loss: 0.2747 - pothole_accuracy: 0.9933 - pothole_level_accuracy: 0.8883 - val_loss: 2.0130 - val_pothole_loss: 0.7278 - val_pothole_level_loss: 1.2852 - val_pothole_accuracy: 0.8872 - val_pothole_level_accuracy: 0.8572
# Epoch 32/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.2986 - pothole_loss: 0.0265 - pothole_level_loss: 0.2721 - pothole_accuracy: 0.9910 - pothole_level_accuracy: 0.8862 - val_loss: 1.5288 - val_pothole_loss: 0.8066 - val_pothole_level_loss: 0.7222 - val_pothole_accuracy: 0.8808 - val_pothole_level_accuracy: 0.8477
# Epoch 33/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.2915 - pothole_loss: 0.0212 - pothole_level_loss: 0.2704 - pothole_accuracy: 0.9918 - pothole_level_accuracy: 0.8902 - val_loss: 1.3610 - val_pothole_loss: 0.7328 - val_pothole_level_loss: 0.6282 - val_pothole_accuracy: 0.8687 - val_pothole_level_accuracy: 0.8238
# Epoch 34/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.2853 - pothole_loss: 0.0216 - pothole_level_loss: 0.2637 - pothole_accuracy: 0.9927 - pothole_level_accuracy: 0.8914 - val_loss: 1.5197 - val_pothole_loss: 0.7049 - val_pothole_level_loss: 0.8148 - val_pothole_accuracy: 0.8863 - val_pothole_level_accuracy: 0.8016
# 210/210 [==============================] - 229s 1s/step - loss: 0.2853 - pothole_loss: 0.0216 - pothole_level_loss: 0.2637 - pothole_accuracy: 0.9927 - pothole_level_accuracy: 0.8914 - val_loss: 1.5197 - val_pothole_loss: 0.7049 - val_pothole_level_loss: 0.8148 - val_pothole_accuracy: 0.8863 - val_pothole_level_accuracy: 0.8016
# Epoch 35/50
# Epoch 35/50
# 210/210 [==============================] - 228s 1s/step - loss: 0.2855 - pothole_loss: 0.0205 - pothole_level_loss: 0.2650 - pothole_accuracy: 0.9929 - pothole_level_accuracy: 0.8909 - val_loss: 1.7770 - val_pothole_loss: 0.9601 - val_pothole_level_loss: 0.8169 - val_pothole_accuracy: 0.7779 - val_pothole_level_accuracy: 0.7366
# 210/210 [==============================] - 228s 1s/step - loss: 0.2855 - pothole_loss: 0.0205 - pothole_level_loss: 0.2650 - pothole_accuracy: 0.9929 - pothole_level_accuracy: 0.8909 - val_loss: 1.7770 - val_pothole_loss: 0.9601 - val_pothole_level_loss: 0.8169 - val_pothole_accuracy: 0.7779 - val_pothole_level_accuracy: 0.7366
# Epoch 36/50
# Epoch 36/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.2609 - pothole_loss: 0.0139 - pothole_level_loss: 0.2470 - pothole_accuracy: 0.9955 - pothole_level_accuracy: 0.8950 - val_loss: 1.4455 - val_pothole_loss: 0.8138 - val_pothole_level_loss: 0.6317 - val_pothole_accuracy: 0.8171 - val_pothole_level_accuracy: 0.7810
# 210/210 [==============================] - 229s 1s/step - loss: 0.2609 - pothole_loss: 0.0139 - pothole_level_loss: 0.2470 - pothole_accuracy: 0.9955 - pothole_level_accuracy: 0.8950 - val_loss: 1.4455 - val_pothole_loss: 0.8138 - val_pothole_level_loss: 0.6317 - val_pothole_accuracy: 0.8171 - val_pothole_level_accuracy: 0.7810
# Epoch 37/50
# Epoch 37/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.2644 - pothole_loss: 0.0158 - pothole_level_loss: 0.2487 - pothole_accuracy: 0.9947 - pothole_level_accuracy: 0.8989 - val_loss: 1.9336 - val_pothole_loss: 1.0192 - val_pothole_level_loss: 0.9144 - val_pothole_accuracy: 0.8879 - val_pothole_level_accuracy: 0.8486
# 210/210 [==============================] - 229s 1s/step - loss: 0.2644 - pothole_loss: 0.0158 - pothole_level_loss: 0.2487 - pothole_accuracy: 0.9947 - pothole_level_accuracy: 0.8989 - val_loss: 1.9336 - val_pothole_loss: 1.0192 - val_pothole_level_loss: 0.9144 - val_pothole_accuracy: 0.8879 - val_pothole_level_accuracy: 0.8486
# Epoch 38/50
# Epoch 38/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.2740 - pothole_loss: 0.0207 - pothole_level_loss: 0.2532 - pothole_accuracy: 0.9930 - pothole_level_accuracy: 0.8964 - val_loss: 1.4939 - val_pothole_loss: 0.6584 - val_pothole_level_loss: 0.8355 - val_pothole_accuracy: 0.8964 - val_pothole_level_accuracy: 0.8542
# 210/210 [==============================] - 229s 1s/step - loss: 0.2740 - pothole_loss: 0.0207 - pothole_level_loss: 0.2532 - pothole_accuracy: 0.9930 - pothole_level_accuracy: 0.8964 - val_loss: 1.4939 - val_pothole_loss: 0.6584 - val_pothole_level_loss: 0.8355 - val_pothole_accuracy: 0.8964 - val_pothole_level_accuracy: 0.8542
# Epoch 39/50
# Epoch 39/50
# 210/210 [==============================] - 230s 1s/step - loss: 0.2714 - pothole_loss: 0.0190 - pothole_level_loss: 0.2524 - pothole_accuracy: 0.9934 - pothole_level_accuracy: 0.8949 - val_loss: 1.3725 - val_pothole_loss: 0.6855 - val_pothole_level_loss: 0.6870 - val_pothole_accuracy: 0.8856 - val_pothole_level_accuracy: 0.8286
# 210/210 [==============================] - 230s 1s/step - loss: 0.2714 - pothole_loss: 0.0190 - pothole_level_loss: 0.2524 - pothole_accuracy: 0.9934 - pothole_level_accuracy: 0.8949 - val_loss: 1.3725 - val_pothole_loss: 0.6855 - val_pothole_level_loss: 0.6870 - val_pothole_accuracy: 0.8856 - val_pothole_level_accuracy: 0.8286
# Epoch 40/50
# Epoch 40/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.2508 - pothole_loss: 0.0148 - pothole_level_loss: 0.2360 - pothole_accuracy: 0.9951 - pothole_level_accuracy: 0.9012 - val_loss: 1.6879 - val_pothole_loss: 0.7464 - val_pothole_level_loss: 0.9415 - val_pothole_accuracy: 0.8783 - val_pothole_level_accuracy: 0.8490
# 210/210 [==============================] - 229s 1s/step - loss: 0.2508 - pothole_loss: 0.0148 - pothole_level_loss: 0.2360 - pothole_accuracy: 0.9951 - pothole_level_accuracy: 0.9012 - val_loss: 1.6879 - val_pothole_loss: 0.7464 - val_pothole_level_loss: 0.9415 - val_pothole_accuracy: 0.8783 - val_pothole_level_accuracy: 0.8490
# Epoch 41/50
# Epoch 41/50
# 210/210 [==============================] - 229s 1s/step - loss: 0.2611 - pothole_loss: 0.0238 - pothole_level_loss: 0.2373 - pothole_accuracy: 0.9920 - pothole_level_accuracy: 0.8995 - val_loss: 1.4668 - val_pothole_loss: 0.6276 - val_pothole_level_loss: 0.8392 - val_pothole_accuracy: 0.8968 - val_pothole_level_accuracy: 0.8393
# 210/210 [==============================] - 229s 1s/step - loss: 0.2611 - pothole_loss: 0.0238 - pothole_level_loss: 0.2373 - pothole_accuracy: 0.9920 - pothole_level_accuracy: 0.8995 - val_loss: 1.4668 - val_pothole_loss: 0.6276 - val_pothole_level_loss: 0.8392 - val_pothole_accuracy: 0.8968 - val_pothole_level_accuracy: 0.8393
# Epoch 42/50
# Epoch 42/50
# 210/210 [==============================] - 228s 1s/step - loss: 0.2795 - pothole_loss: 0.0319 - pothole_level_loss: 0.2475 - pothole_accuracy: 0.9890 - pothole_level_accuracy: 0.8983 - val_loss: 8.1628 - val_pothole_loss: 5.2623 - val_pothole_level_loss: 2.9004 - val_pothole_accuracy: 0.7307 - val_pothole_level_accuracy: 0.8097
# 210/210 [==============================] - 228s 1s/step - loss: 0.2795 - pothole_loss: 0.0319 - pothole_level_loss: 0.2475 - pothole_accuracy: 0.9890 - pothole_level_accuracy: 0.8983 - val_loss: 8.1628 - val_pothole_loss: 5.2623 - val_pothole_level_loss: 2.9004 - val_pothole_accuracy: 0.7307 - val_pothole_level_accuracy: 0.8097
# Epoch 43/50
# Epoch 43/50
# 210/210 [==============================] - 228s 1s/step - loss: 0.2665 - pothole_loss: 0.0270 - pothole_level_loss: 0.2394 - pothole_accuracy: 0.9907 - pothole_level_accuracy: 0.8983 - val_loss: 1.8032 - val_pothole_loss: 0.8180 - val_pothole_level_loss: 0.9852 - val_pothole_accuracy: 0.8993 - val_pothole_level_accuracy: 0.8483
# 210/210 [==============================] - 228s 1s/step - loss: 0.2665 - pothole_loss: 0.0270 - pothole_level_loss: 0.2394 - pothole_accuracy: 0.9907 - pothole_level_accuracy: 0.8983 - val_loss: 1.8032 - val_pothole_loss: 0.8180 - val_pothole_level_loss: 0.9852 - val_pothole_accuracy: 0.8993 - val_pothole_level_accuracy: 0.8483
# Epoch 44/50
# Epoch 44/50
# 210/210 [==============================] - 228s 1s/step - loss: 0.2399 - pothole_loss: 0.0141 - pothole_level_loss: 0.2258 - pothole_accuracy: 0.9955 - pothole_level_accuracy: 0.9035 - val_loss: 1.6128 - val_pothole_loss: 0.8575 - val_pothole_level_loss: 0.7554 - val_pothole_accuracy: 0.8502 - val_pothole_level_accuracy: 0.7870
# 210/210 [==============================] - 228s 1s/step - loss: 0.2399 - pothole_loss: 0.0141 - pothole_level_loss: 0.2258 - pothole_accuracy: 0.9955 - pothole_level_accuracy: 0.9035 - val_loss: 1.6128 - val_pothole_loss: 0.8575 - val_pothole_level_loss: 0.7554 - val_pothole_accuracy: 0.8502 - val_pothole_level_accuracy: 0.7870
# Epoch 45/50
# Epoch 45/50
# 210/210 [==============================] - 228s 1s/step - loss: 0.2362 - pothole_loss: 0.0130 - pothole_level_loss: 0.2232 - pothole_accuracy: 0.9955 - pothole_level_accuracy: 0.9047 - val_loss: 1.9297 - val_pothole_loss: 0.9442 - val_pothole_level_loss: 0.9855 - val_pothole_accuracy: 0.8928 - val_pothole_level_accuracy: 0.7913
# 210/210 [==============================] - 228s 1s/step - loss: 0.2362 - pothole_loss: 0.0130 - pothole_level_loss: 0.2232 - pothole_accuracy: 0.9955 - pothole_level_accuracy: 0.9047 - val_loss: 1.9297 - val_pothole_loss: 0.9442 - val_pothole_level_loss: 0.9855 - val_pothole_accuracy: 0.8928 - val_pothole_level_accuracy: 0.7913
# Epoch 46/50
# Epoch 46/50
# 210/210 [==============================] - 228s 1s/step - loss: 0.2225 - pothole_loss: 0.0097 - pothole_level_loss: 0.2127 - pothole_accuracy: 0.9969 - pothole_level_accuracy: 0.9083 - val_loss: 2.2085 - val_pothole_loss: 0.8188 - val_pothole_level_loss: 1.3897 - val_pothole_accuracy: 0.9031 - val_pothole_level_accuracy: 0.7981
# 210/210 [==============================] - 228s 1s/step - loss: 0.2225 - pothole_loss: 0.0097 - pothole_level_loss: 0.2127 - pothole_accuracy: 0.9969 - pothole_level_accuracy: 0.9083 - val_loss: 2.2085 - val_pothole_loss: 0.8188 - val_pothole_level_loss: 1.3897 - val_pothole_accuracy: 0.9031 - val_pothole_level_accuracy: 0.7981
# Epoch 47/50
# Epoch 47/50
# 210/210 [==============================] - 228s 1s/step - loss: 0.2232 - pothole_loss: 0.0111 - pothole_level_loss: 0.2121 - pothole_accuracy: 0.9957 - pothole_level_accuracy: 0.9074 - val_loss: 6.2371 - val_pothole_loss: 3.3505 - val_pothole_level_loss: 2.8866 - val_pothole_accuracy: 0.7464 - val_pothole_level_accuracy: 0.8021
# 210/210 [==============================] - 228s 1s/step - loss: 0.2232 - pothole_loss: 0.0111 - pothole_level_loss: 0.2121 - pothole_accuracy: 0.9957 - pothole_level_accuracy: 0.9074 - val_loss: 6.2371 - val_pothole_loss: 3.3505 - val_pothole_level_loss: 2.8866 - val_pothole_accuracy: 0.7464 - val_pothole_level_accuracy: 0.8021
# Epoch 48/50
# Epoch 48/50
# 210/210 [==============================] - 228s 1s/step - loss: 0.2197 - pothole_loss: 0.0087 - pothole_level_loss: 0.2110 - pothole_accuracy: 0.9972 - pothole_level_accuracy: 0.9086 - val_loss: 1.8299 - val_pothole_loss: 1.1557 - val_pothole_level_loss: 0.6742 - val_pothole_accuracy: 0.8628 - val_pothole_level_accuracy: 0.8157
# 210/210 [==============================] - 228s 1s/step - loss: 0.2197 - pothole_loss: 0.0087 - pothole_level_loss: 0.2110 - pothole_accuracy: 0.9972 - pothole_level_accuracy: 0.9086 - val_loss: 1.8299 - val_pothole_loss: 1.1557 - val_pothole_level_loss: 0.6742 - val_pothole_accuracy: 0.8628 - val_pothole_level_accuracy: 0.8157
# Epoch 49/50
# Epoch 49/50
# 210/210 [==============================] - 228s 1s/step - loss: 0.2156 - pothole_loss: 0.0093 - pothole_level_loss: 0.2063 - pothole_accuracy: 0.9970 - pothole_level_accuracy: 0.9120 - val_loss: 1.9305 - val_pothole_loss: 1.1593 - val_pothole_level_loss: 0.7712 - val_pothole_accuracy: 0.8879 - val_pothole_level_accuracy: 0.8437
# 210/210 [==============================] - 228s 1s/step - loss: 0.2156 - pothole_loss: 0.0093 - pothole_level_loss: 0.2063 - pothole_accuracy: 0.9970 - pothole_level_accuracy: 0.9120 - val_loss: 1.9305 - val_pothole_loss: 1.1593 - val_pothole_level_loss: 0.7712 - val_pothole_accuracy: 0.8879 - val_pothole_level_accuracy: 0.8437
# Epoch 50/50
# Epoch 50/50
# 210/210 [==============================] - 228s 1s/step - loss: 0.2170 - pothole_loss: 0.0121 - pothole_level_loss: 0.2049 - pothole_accuracy: 0.9959 - pothole_level_accuracy: 0.9136 - val_loss: 2.0917 - val_pothole_loss: 1.3504 - val_pothole_level_loss: 0.7413 - val_pothole_accuracy: 0.8869 - val_pothole_level_accuracy: 0.8199
# 210/210 [==============================] - 228s 1s/step - loss: 0.2170 - pothole_loss: 0.0121 - pothole_level_loss: 0.2049 - pothole_accuracy: 0.9959 - pothole_level_accuracy: 0.9136 - val_loss: 2.0917 - val_pothole_loss: 1.3504 - val_pothole_level_loss: 0.7413 - val_pothole_accuracy: 0.8869 - val_pothole_level_accuracy: 0.8199

# %%
model.save("pothole_detection_model_prototype_2_adam.h5")

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

tflite_model_quant = converter.convert()

open("pothole_detection_model_prototype_2_sgd.tflite" , "wb").write(tflite_model_quant)
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input Layer with unsupported characters which will be renamed to placeholder in the SavedModel.
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input Layer with unsupported characters which will be renamed to placeholder in the SavedModel.
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
