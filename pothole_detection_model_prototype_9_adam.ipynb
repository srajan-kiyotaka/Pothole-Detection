# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !git clone "https://github.com/srajan-kiyotaka/Pothole-Detection.git"
# Out:
# fatal: destination path 'Pothole-Detection' already exists and is not an empty directory.

# %%
# Importing the csv file

import pandas as pd
import numpy as np

features = pd.read_csv(r"/content/Pothole-Detection/Dataset_Info.csv")

features.head(10)
# Out:
#               Image ID  Pothole  Number of Potholes Level  Unnamed: 4
# 0   pothole_image_1299        1                   3     B         NaN
# 1  pothole_image_10064        1                   1     A         NaN
# 2  pothole_image_10079        1                   1     A         NaN
# 3  pothole_image_10084        1                   1     A         NaN
# 4  pothole_image_10087        1                   2     A         NaN
# 5  pothole_image_10110        1                   1     A         NaN
# 6  pothole_image_10119        1                   1     A         NaN
# 7  pothole_image_10120        1                   1     A         NaN
# 8  pothole_image_10135        1                   1     A         NaN
# 9  pothole_image_10139        1                   1     A         NaN

# %%
features.isna().sum()
# Out:
# Image ID                  0
# Pothole                   0
# Number of Potholes        0
# Level                     0
# Unnamed: 4            30000
# dtype: int64

# %%
features = features.drop('Unnamed: 4', axis = 1)

# %%
features.head(10)
# Out:
#               Image ID  Pothole  Number of Potholes Level
# 0   pothole_image_1299        1                   3     B
# 1  pothole_image_10064        1                   1     A
# 2  pothole_image_10079        1                   1     A
# 3  pothole_image_10084        1                   1     A
# 4  pothole_image_10087        1                   2     A
# 5  pothole_image_10110        1                   1     A
# 6  pothole_image_10119        1                   1     A
# 7  pothole_image_10120        1                   1     A
# 8  pothole_image_10135        1                   1     A
# 9  pothole_image_10139        1                   1     A

# %%
features.isna().sum()
# Out:
# Image ID              0
# Pothole               0
# Number of Potholes    0
# Level                 0
# dtype: int64

# %%
all_image_names = features['Image ID']
features = features.drop('Image ID', axis = 1)

pothole_or_not = features['Pothole']
pothole_info = features['Number of Potholes']
pothole_level = features['Level']

pothole_or_not = pd.get_dummies(pothole_or_not, columns = ['Pothole'])
pothole_or_not.columns = ['Normal Road', 'Pothole']
pothole_level = pd.get_dummies(pothole_level, columns = ['Level'])

features = pothole_or_not.join(pothole_info)
features = features.join(pothole_level)

print(features.head(10))
# Out:
#    Normal Road  Pothole  Number of Potholes  A  B  C  S
# 0            0        1                   3  0  1  0  0
# 1            0        1                   1  1  0  0  0
# 2            0        1                   1  1  0  0  0
# 3            0        1                   1  1  0  0  0
# 4            0        1                   2  1  0  0  0
# 5            0        1                   1  1  0  0  0
# 6            0        1                   1  1  0  0  0
# 7            0        1                   1  1  0  0  0
# 8            0        1                   1  1  0  0  0
# 9            0        1                   1  1  0  0  0

# %%
from sklearn.utils import shuffle

image_names_shuffled, labels_shuffled = shuffle(all_image_names, features)

# %%
from sklearn.model_selection import train_test_split

X_train_image_names, X_test_image_names, y_train, y_test = train_test_split(
    image_names_shuffled, labels_shuffled, test_size=0.3, random_state=1)

# %%
type(y_train)
# Out:
# pandas.core.frame.DataFrame

# %%
train_pothole_or_not = y_train[['Normal Road', 'Pothole']]
train_pothole_info = y_train['Number of Potholes']
train_pothole_level = y_train[['A', 'B', 'C', 'S']]

test_pothole_or_not = y_test[['Normal Road', 'Pothole']]
test_pothole_info = y_test['Number of Potholes']
test_pothole_level = y_test[['A', 'B', 'C', 'S']]

# %%
y_train.shape
# Out:
# (21000, 7)

# %%
train_pothole_or_not = np.array(train_pothole_or_not)
train_pothole_info = np.array(train_pothole_info)
train_pothole_level = np.array(train_pothole_level)

test_pothole_or_not = np.array(test_pothole_or_not)
test_pothole_info = np.array(test_pothole_info)
test_pothole_level = np.array(test_pothole_level)

# %%
import cv2

def get_image(file_location):
    img = cv2.imread(file_location)
    # img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    # img = img/255
    img = cv2.resize(img,(160, 160))
    return img

# %%
import keras
import numpy as np

class My_Custom_Generator(keras.utils.all_utils.Sequence) :
  
  def __init__(self, image_filenames, pothole, pothole_number, pothole_level, batch_size = 128) :
    self.image_filenames = image_filenames
    self.pothole = pothole
    self.pothole_number = pothole_number
    self.pothole_level = pothole_level
    self.batch_size = batch_size
    
    
  def __len__(self) :
    return (np.ceil(len(self.image_filenames) / float(self.batch_size))).astype(np.int)
  
  
  def __getitem__(self, idx) :
    batch_x = self.image_filenames[idx * self.batch_size : (idx+1) * self.batch_size]
    a = self.pothole[idx * self.batch_size : (idx+1) * self.batch_size]
    # b = self.pothole_number[idx * self.batch_size : (idx+1) * self.batch_size]
    c = self.pothole_level[idx * self.batch_size : (idx+1) * self.batch_size]
    batch_y = [np.array(a), np.array(c)] #, np.array(c)]

    return np.array([
            get_image(f'/content/Pothole-Detection/Unified Dataset/{str(file_name)}.jpg')
               for file_name in batch_x]), batch_y

# %%
batch_size = 80

my_training_batch_generator = My_Custom_Generator(X_train_image_names, train_pothole_or_not, train_pothole_info, train_pothole_level, batch_size)
my_validation_batch_generator = My_Custom_Generator(X_test_image_names, test_pothole_or_not, test_pothole_info, test_pothole_level, batch_size)

# %%
import tensorflow as tf
from keras.models import Sequential, Model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Input, Activation, Add, BatchNormalization, Rescaling

input_ = Input(shape = (160, 160, 3), name = "Input Layer")

rescale = Rescaling(scale=1./255)(input_)

conv_1 = Conv2D(64, kernel_size = (8, 8), name = "conv_1")(rescale)
act_1 = Activation("relu", name = "act_1")(conv_1)
pool_1 = MaxPooling2D(pool_size = (8, 8), strides = (1, 1), padding = "valid", name = "pool_1")(act_1)

conv_2 = Conv2D(32, kernel_size = (4, 4), name = "conv_2")(pool_1)
act_2 = Activation("relu", name = "act_2")(conv_2)
pool_2 = MaxPooling2D(pool_size = (8, 8), strides = (1, 1), padding = "valid", name = "pool_2")(act_2)

conv_3 = Conv2D(16, kernel_size = (8, 8), name = "conv_3")(pool_2)
act_3 = Activation("relu", name = "act_3")(conv_3)
pool_3 = MaxPooling2D(pool_size = (16, 16), strides = (1, 1), padding = "valid", name = "pool_3")(act_3)

flat_1 = Flatten(name = "flat_1")(pool_3)

dense_1 = Dense(128, activation = "relu", name = "dense_1")(flat_1)
batch_1 = BatchNormalization(name = "batch_1")(dense_1)
dense_2 = Dense(256, activation = "relu", name = "dense_2")(batch_1)
batch_2 = BatchNormalization(name = "batch_2")(dense_2)
dense_3 = Dense(64, activation = "relu", name = "dense_3")(batch_2)
isPothole = Dense(2, activation = "softmax", name = "pothole")(dense_3)

conv_4 = Conv2D(8, kernel_size = (4, 4), name = "conv_4")(pool_3)
act_4 = Activation("relu", name = "act_4")(conv_4)
pool_4 = MaxPooling2D(pool_size = (16, 16), strides = (1, 1), padding = "valid", name = "pool_4")(act_4)

# flat_2 = Flatten(name = "flat_2")(pool_4)

# dense_4 = Dense(128, activation = "relu", name = "dense_4")(flat_2)
# batch_3 = BatchNormalization(name = "batch_3")(dense_4)
# add_1 = Add(name = "add_1")([batch_1, batch_3])

# dense_5 = Dense(64, activation = "relu", name = "dense_5")(add_1)
# batch_4 = BatchNormalization(name = "batch_4")(dense_5)
# pothole_num = Dense(1, activation = "relu", name = "pothole_number")(batch_2)

# conv_5 = Conv2D(16, kernel_size = (8, 8), name = "conv_5")(pool_4)
# act_5 = Activation("relu", name = "act_5")(conv_5)
# pool_5 = MaxPooling2D(pool_size = (4, 4), strides = (1, 1), padding = "valid", name = "pool_5")(act_5)

flat_2 = Flatten(name = "flat_2")(pool_4)

dense_4 = Dense(128, activation = "relu", name = "dense_4")(flat_2)
batch_5 = BatchNormalization(name = "batch_5")(dense_4)
add_2 = Add(name = "add_2")([batch_1, batch_5])
batch_6 = BatchNormalization(name = "batch_6")(add_2)
dense_5 = Dense(256, activation = "relu", name = "dense_5")(batch_6)
drop_2 = Dropout(rate = 0.4, name = "drop_2")(dense_5)
# add_3 = Add(name = "add_3")([batch_7, batch_2])
dense_6 = Dense(72, activation = "relu", name = "dense_6")(drop_2)
batch_7 = BatchNormalization(name = "batch_7")(dense_6)
dense_7 = Dense(64, activation = "relu", name = "dense_7")(batch_7)
drop_3 = Dropout(rate = 0.4, name = "drop_3")(dense_7)
dense_8 = Dense(32, activation = "relu", name = "dense_8")(drop_3)
pothole_level = Dense(4, activation = "softmax", name = "pothole_level")(dense_8)

model = Model(inputs = input_, outputs = [isPothole, pothole_level])

opt = tf.keras.optimizers.Adam(learning_rate = 0.001)

model.compile(
              loss = {
                  'pothole' : 'categorical_crossentropy',
                #   'pothole_number' : 'categorical_crossentropy'
                  'pothole_level' : 'categorical_crossentropy'
              },
              optimizer = opt,
              metrics = ['accuracy']
)

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input Layer (InputLayer)       [(None, 160, 160, 3  0           []
#                                 )]
#
#  rescaling_1 (Rescaling)        (None, 160, 160, 3)  0           ['Input Layer[0][0]']
#
#  conv_1 (Conv2D)                (None, 153, 153, 64  12352       ['rescaling_1[0][0]']
#                                 )
#
#  act_1 (Activation)             (None, 153, 153, 64  0           ['conv_1[0][0]']
#                                 )
#
#  pool_1 (MaxPooling2D)          (None, 146, 146, 64  0           ['act_1[0][0]']
#                                 )
#
#  conv_2 (Conv2D)                (None, 143, 143, 32  32800       ['pool_1[0][0]']
#                                 )
#
#  act_2 (Activation)             (None, 143, 143, 32  0           ['conv_2[0][0]']
#                                 )
#
#  pool_2 (MaxPooling2D)          (None, 136, 136, 32  0           ['act_2[0][0]']
#                                 )
#
#  conv_3 (Conv2D)                (None, 129, 129, 16  32784       ['pool_2[0][0]']
#                                 )
#
#  act_3 (Activation)             (None, 129, 129, 16  0           ['conv_3[0][0]']
#                                 )
#
#  pool_3 (MaxPooling2D)          (None, 114, 114, 16  0           ['act_3[0][0]']
#                                 )
#
#  conv_4 (Conv2D)                (None, 111, 111, 8)  2056        ['pool_3[0][0]']
#
#  act_4 (Activation)             (None, 111, 111, 8)  0           ['conv_4[0][0]']
#
#  pool_4 (MaxPooling2D)          (None, 96, 96, 8)    0           ['act_4[0][0]']
#
#  flat_1 (Flatten)               (None, 207936)       0           ['pool_3[0][0]']
#
#  flat_2 (Flatten)               (None, 73728)        0           ['pool_4[0][0]']
#
#  dense_1 (Dense)                (None, 128)          26615936    ['flat_1[0][0]']
#
#  dense_4 (Dense)                (None, 128)          9437312     ['flat_2[0][0]']
#
#  batch_1 (BatchNormalization)   (None, 128)          512         ['dense_1[0][0]']
#
#  batch_5 (BatchNormalization)   (None, 128)          512         ['dense_4[0][0]']
#
#  add_2 (Add)                    (None, 128)          0           ['batch_1[0][0]',
#                                                                   'batch_5[0][0]']
#
#  batch_6 (BatchNormalization)   (None, 128)          512         ['add_2[0][0]']
#
#  dense_5 (Dense)                (None, 256)          33024       ['batch_6[0][0]']
#
#  drop_2 (Dropout)               (None, 256)          0           ['dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 72)           18504       ['drop_2[0][0]']
#
#  batch_7 (BatchNormalization)   (None, 72)           288         ['dense_6[0][0]']
#
#  dense_2 (Dense)                (None, 256)          33024       ['batch_1[0][0]']
#
#  dense_7 (Dense)                (None, 64)           4672        ['batch_7[0][0]']
#
#  batch_2 (BatchNormalization)   (None, 256)          1024        ['dense_2[0][0]']
#
#  drop_3 (Dropout)               (None, 64)           0           ['dense_7[0][0]']
#
#  dense_3 (Dense)                (None, 64)           16448       ['batch_2[0][0]']
#
#  dense_8 (Dense)                (None, 32)           2080        ['drop_3[0][0]']
#
#  pothole (Dense)                (None, 2)            130         ['dense_3[0][0]']
#
#  pothole_level (Dense)          (None, 4)            132         ['dense_8[0][0]']
#
# ==================================================================================================
# Total params: 36,244,102
# Trainable params: 36,242,678
# Non-trainable params: 1,424
# __________________________________________________________________________________________________

# %%
keras.utils.all_utils.plot_model(model, "model.png", show_shapes = True, show_layer_names = True)

# %%
# class Logger(keras.callbacks.Callback):
#   def on_epoch_end(self, epoch, logs=None):
#     pothole_accuracy = logs.get('pothole_accuracy')
#     pothole_number_accuracy = logs.get('pothole_number_accuracy')
#     pothole_level_accuracy = logs.get('pothole_level_accuracy')

#     val_pothole_accuracy = logs.get('val_pothole_accuracy')
#     val_pothole_number_accuracy = logs.get('val_pothole_number_accuracy')
#     val_pothole_level_accuracy = logs.get('val_pothole_level_accuracy')

#     print('='*30, epoch + 1, '='*30)
#     print(f'pothole_accuracy: {pothole_accuracy:.2f}, pothole_number_accuracy: {pothole_number_accuracy:.2f}, pothole_level_accuracy: {pothole_level_accuracy:.2f}')
#     print(f'val_pothole_accuracy: {val_pothole_accuracy:.2f}, val_pothole_number_accuracy: {val_pothole_number_accuracy:.2f}, val_pothole_level_accuracy:{val_pothole_level_accuracy:.2f}')

# %%
_ = model.fit_generator(generator=my_training_batch_generator,
                   steps_per_epoch = int(21000 // batch_size),
                   epochs = 53,
                #    verbose = False,
                   validation_data = my_validation_batch_generator,
                #    callbacks = [
                #                 Logger(),
                #                 keras.callbacks.TensorBoard(log_dir = './logs')
                #                 ],
                   validation_steps = int(9000 // batch_size))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app
# Epoch 1/53
# 262/262 [==============================] - 158s 535ms/step - loss: 1.0470 - pothole_loss: 0.3861 - pothole_level_loss: 0.6608 - pothole_accuracy: 0.8458 - pothole_level_accuracy: 0.7710 - val_loss: 9.7485 - val_pothole_loss: 5.8277 - val_pothole_level_loss: 3.9208 - val_pothole_accuracy: 0.7214 - val_pothole_level_accuracy: 0.7738
# Epoch 2/53
# 262/262 [==============================] - 136s 517ms/step - loss: 0.9291 - pothole_loss: 0.3390 - pothole_level_loss: 0.5901 - pothole_accuracy: 0.8665 - pothole_level_accuracy: 0.7935 - val_loss: 1.0709 - val_pothole_loss: 0.4498 - val_pothole_level_loss: 0.6211 - val_pothole_accuracy: 0.8304 - val_pothole_level_accuracy: 0.7848
# Epoch 3/53
# 262/262 [==============================] - 135s 514ms/step - loss: 0.8807 - pothole_loss: 0.3190 - pothole_level_loss: 0.5617 - pothole_accuracy: 0.8775 - pothole_level_accuracy: 0.8089 - val_loss: 1.7093 - val_pothole_loss: 0.7942 - val_pothole_level_loss: 0.9150 - val_pothole_accuracy: 0.7198 - val_pothole_level_accuracy: 0.7728
# Epoch 4/53
# 262/262 [==============================] - 133s 507ms/step - loss: 0.8667 - pothole_loss: 0.3148 - pothole_level_loss: 0.5519 - pothole_accuracy: 0.8792 - pothole_level_accuracy: 0.8136 - val_loss: 1.3542 - val_pothole_loss: 0.3190 - val_pothole_level_loss: 1.0352 - val_pothole_accuracy: 0.8837 - val_pothole_level_accuracy: 0.7742
# Epoch 5/53
# 262/262 [==============================] - 133s 507ms/step - loss: 0.7751 - pothole_loss: 0.2778 - pothole_level_loss: 0.4974 - pothole_accuracy: 0.8962 - pothole_level_accuracy: 0.8382 - val_loss: 1.0063 - val_pothole_loss: 0.4129 - val_pothole_level_loss: 0.5933 - val_pothole_accuracy: 0.8164 - val_pothole_level_accuracy: 0.8047
# Epoch 6/53
# 262/262 [==============================] - 134s 510ms/step - loss: 0.7504 - pothole_loss: 0.2679 - pothole_level_loss: 0.4824 - pothole_accuracy: 0.9003 - pothole_level_accuracy: 0.8436 - val_loss: 0.8927 - val_pothole_loss: 0.3215 - val_pothole_level_loss: 0.5712 - val_pothole_accuracy: 0.8763 - val_pothole_level_accuracy: 0.8048
# Epoch 7/53
# 262/262 [==============================] - 132s 504ms/step - loss: 0.7186 - pothole_loss: 0.2534 - pothole_level_loss: 0.4652 - pothole_accuracy: 0.9050 - pothole_level_accuracy: 0.8502 - val_loss: 0.8258 - val_pothole_loss: 0.3448 - val_pothole_level_loss: 0.4810 - val_pothole_accuracy: 0.8787 - val_pothole_level_accuracy: 0.8530
# Epoch 8/53
# 262/262 [==============================] - 132s 505ms/step - loss: 0.6995 - pothole_loss: 0.2442 - pothole_level_loss: 0.4553 - pothole_accuracy: 0.9099 - pothole_level_accuracy: 0.8533 - val_loss: 1.9110 - val_pothole_loss: 0.5483 - val_pothole_level_loss: 1.3627 - val_pothole_accuracy: 0.7615 - val_pothole_level_accuracy: 0.7741
# Epoch 9/53
# 262/262 [==============================] - 131s 498ms/step - loss: 0.7145 - pothole_loss: 0.2526 - pothole_level_loss: 0.4619 - pothole_accuracy: 0.9071 - pothole_level_accuracy: 0.8503 - val_loss: 2.6147 - val_pothole_loss: 0.5594 - val_pothole_level_loss: 2.0553 - val_pothole_accuracy: 0.8356 - val_pothole_level_accuracy: 0.7739
# Epoch 10/53
# 262/262 [==============================] - 130s 494ms/step - loss: 0.6874 - pothole_loss: 0.2371 - pothole_level_loss: 0.4503 - pothole_accuracy: 0.9124 - pothole_level_accuracy: 0.8546 - val_loss: 5.7520 - val_pothole_loss: 0.5218 - val_pothole_level_loss: 5.2301 - val_pothole_accuracy: 0.8614 - val_pothole_level_accuracy: 0.7488
# Epoch 11/53
# 262/262 [==============================] - 131s 499ms/step - loss: 0.6720 - pothole_loss: 0.2309 - pothole_level_loss: 0.4411 - pothole_accuracy: 0.9141 - pothole_level_accuracy: 0.8587 - val_loss: 0.9129 - val_pothole_loss: 0.3382 - val_pothole_level_loss: 0.5747 - val_pothole_accuracy: 0.8813 - val_pothole_level_accuracy: 0.8249
# Epoch 12/53
# 262/262 [==============================] - 130s 496ms/step - loss: 0.6558 - pothole_loss: 0.2217 - pothole_level_loss: 0.4341 - pothole_accuracy: 0.9170 - pothole_level_accuracy: 0.8601 - val_loss: 0.8701 - val_pothole_loss: 0.3241 - val_pothole_level_loss: 0.5460 - val_pothole_accuracy: 0.8766 - val_pothole_level_accuracy: 0.8263
# Epoch 13/53
# 262/262 [==============================] - 129s 494ms/step - loss: 0.6428 - pothole_loss: 0.2145 - pothole_level_loss: 0.4283 - pothole_accuracy: 0.9207 - pothole_level_accuracy: 0.8607 - val_loss: 0.8078 - val_pothole_loss: 0.3163 - val_pothole_level_loss: 0.4915 - val_pothole_accuracy: 0.8857 - val_pothole_level_accuracy: 0.8382
# Epoch 14/53
# 262/262 [==============================] - 130s 497ms/step - loss: 0.6318 - pothole_loss: 0.2083 - pothole_level_loss: 0.4234 - pothole_accuracy: 0.9225 - pothole_level_accuracy: 0.8620 - val_loss: 1.0958 - val_pothole_loss: 0.5545 - val_pothole_level_loss: 0.5413 - val_pothole_accuracy: 0.7905 - val_pothole_level_accuracy: 0.8227
# Epoch 15/53
# 262/262 [==============================] - 130s 496ms/step - loss: 0.6169 - pothole_loss: 0.2027 - pothole_level_loss: 0.4141 - pothole_accuracy: 0.9233 - pothole_level_accuracy: 0.8656 - val_loss: 1.3897 - val_pothole_loss: 0.6643 - val_pothole_level_loss: 0.7254 - val_pothole_accuracy: 0.7523 - val_pothole_level_accuracy: 0.7780
# Epoch 16/53
# 262/262 [==============================] - 131s 500ms/step - loss: 0.5963 - pothole_loss: 0.1912 - pothole_level_loss: 0.4051 - pothole_accuracy: 0.9283 - pothole_level_accuracy: 0.8670 - val_loss: 0.7818 - val_pothole_loss: 0.3028 - val_pothole_level_loss: 0.4790 - val_pothole_accuracy: 0.8801 - val_pothole_level_accuracy: 0.8477
# Epoch 17/53
# 262/262 [==============================] - 130s 495ms/step - loss: 0.5787 - pothole_loss: 0.1811 - pothole_level_loss: 0.3976 - pothole_accuracy: 0.9307 - pothole_level_accuracy: 0.8689 - val_loss: 23.0454 - val_pothole_loss: 1.6997 - val_pothole_level_loss: 21.3457 - val_pothole_accuracy: 0.8347 - val_pothole_level_accuracy: 0.8340
# Epoch 18/53
# 262/262 [==============================] - 130s 496ms/step - loss: 0.5678 - pothole_loss: 0.1746 - pothole_level_loss: 0.3933 - pothole_accuracy: 0.9326 - pothole_level_accuracy: 0.8693 - val_loss: 0.8127 - val_pothole_loss: 0.3304 - val_pothole_level_loss: 0.4823 - val_pothole_accuracy: 0.8797 - val_pothole_level_accuracy: 0.8555
# Epoch 19/53
# 262/262 [==============================] - 131s 499ms/step - loss: 0.5466 - pothole_loss: 0.1610 - pothole_level_loss: 0.3857 - pothole_accuracy: 0.9389 - pothole_level_accuracy: 0.8717 - val_loss: 0.8094 - val_pothole_loss: 0.3786 - val_pothole_level_loss: 0.4308 - val_pothole_accuracy: 0.8911 - val_pothole_level_accuracy: 0.8626
# Epoch 20/53
# 262/262 [==============================] - 130s 495ms/step - loss: 0.5338 - pothole_loss: 0.1540 - pothole_level_loss: 0.3798 - pothole_accuracy: 0.9401 - pothole_level_accuracy: 0.8717 - val_loss: 0.7740 - val_pothole_loss: 0.3029 - val_pothole_level_loss: 0.4711 - val_pothole_accuracy: 0.8968 - val_pothole_level_accuracy: 0.8471
# Epoch 21/53
# 262/262 [==============================] - 130s 496ms/step - loss: 0.5327 - pothole_loss: 0.1538 - pothole_level_loss: 0.3789 - pothole_accuracy: 0.9406 - pothole_level_accuracy: 0.8717 - val_loss: 46.9619 - val_pothole_loss: 1.1169 - val_pothole_level_loss: 45.8450 - val_pothole_accuracy: 0.8234 - val_pothole_level_accuracy: 0.7345
# Epoch 22/53
# 262/262 [==============================] - 130s 497ms/step - loss: 0.5055 - pothole_loss: 0.1356 - pothole_level_loss: 0.3699 - pothole_accuracy: 0.9474 - pothole_level_accuracy: 0.8759 - val_loss: 2.3658 - val_pothole_loss: 0.9057 - val_pothole_level_loss: 1.4600 - val_pothole_accuracy: 0.7551 - val_pothole_level_accuracy: 0.7749
# Epoch 23/53
# 262/262 [==============================] - 130s 495ms/step - loss: 0.5044 - pothole_loss: 0.1367 - pothole_level_loss: 0.3677 - pothole_accuracy: 0.9462 - pothole_level_accuracy: 0.8762 - val_loss: 7.5312 - val_pothole_loss: 0.8466 - val_pothole_level_loss: 6.6846 - val_pothole_accuracy: 0.8050 - val_pothole_level_accuracy: 0.8377
# Epoch 24/53
# 262/262 [==============================] - 130s 496ms/step - loss: 0.4861 - pothole_loss: 0.1255 - pothole_level_loss: 0.3606 - pothole_accuracy: 0.9489 - pothole_level_accuracy: 0.8757 - val_loss: 1.4425 - val_pothole_loss: 0.5628 - val_pothole_level_loss: 0.8797 - val_pothole_accuracy: 0.8230 - val_pothole_level_accuracy: 0.7915
# Epoch 25/53
# 262/262 [==============================] - 131s 501ms/step - loss: 0.4809 - pothole_loss: 0.1237 - pothole_level_loss: 0.3572 - pothole_accuracy: 0.9493 - pothole_level_accuracy: 0.8771 - val_loss: 1.0815 - val_pothole_loss: 0.5589 - val_pothole_level_loss: 0.5226 - val_pothole_accuracy: 0.8431 - val_pothole_level_accuracy: 0.8506
# Epoch 26/53
# 262/262 [==============================] - 130s 497ms/step - loss: 0.4571 - pothole_loss: 0.1092 - pothole_level_loss: 0.3479 - pothole_accuracy: 0.9562 - pothole_level_accuracy: 0.8792 - val_loss: 1.1322 - val_pothole_loss: 0.4294 - val_pothole_level_loss: 0.7028 - val_pothole_accuracy: 0.8691 - val_pothole_level_accuracy: 0.7981
# Epoch 27/53
# 262/262 [==============================] - 130s 496ms/step - loss: 0.4481 - pothole_loss: 0.1022 - pothole_level_loss: 0.3459 - pothole_accuracy: 0.9591 - pothole_level_accuracy: 0.8780 - val_loss: 2.0493 - val_pothole_loss: 0.8778 - val_pothole_level_loss: 1.1715 - val_pothole_accuracy: 0.8006 - val_pothole_level_accuracy: 0.7782
# Epoch 28/53
# 262/262 [==============================] - 130s 496ms/step - loss: 0.4366 - pothole_loss: 0.0973 - pothole_level_loss: 0.3394 - pothole_accuracy: 0.9610 - pothole_level_accuracy: 0.8798 - val_loss: 1.2857 - val_pothole_loss: 0.5401 - val_pothole_level_loss: 0.7455 - val_pothole_accuracy: 0.8574 - val_pothole_level_accuracy: 0.7954
# Epoch 29/53
# 262/262 [==============================] - 130s 494ms/step - loss: 0.4205 - pothole_loss: 0.0862 - pothole_level_loss: 0.3344 - pothole_accuracy: 0.9649 - pothole_level_accuracy: 0.8815 - val_loss: 1.6176 - val_pothole_loss: 0.4896 - val_pothole_level_loss: 1.1280 - val_pothole_accuracy: 0.8866 - val_pothole_level_accuracy: 0.8536
# Epoch 30/53
# 262/262 [==============================] - 131s 499ms/step - loss: 0.4004 - pothole_loss: 0.0747 - pothole_level_loss: 0.3256 - pothole_accuracy: 0.9699 - pothole_level_accuracy: 0.8832 - val_loss: 0.9161 - val_pothole_loss: 0.4249 - val_pothole_level_loss: 0.4912 - val_pothole_accuracy: 0.8694 - val_pothole_level_accuracy: 0.8529
# Epoch 31/53
# 262/262 [==============================] - 130s 497ms/step - loss: 0.3883 - pothole_loss: 0.0702 - pothole_level_loss: 0.3180 - pothole_accuracy: 0.9725 - pothole_level_accuracy: 0.8852 - val_loss: 1.1235 - val_pothole_loss: 0.6123 - val_pothole_level_loss: 0.5113 - val_pothole_accuracy: 0.8693 - val_pothole_level_accuracy: 0.8617
# Epoch 32/53
# 262/262 [==============================] - 130s 495ms/step - loss: 0.3878 - pothole_loss: 0.0715 - pothole_level_loss: 0.3163 - pothole_accuracy: 0.9715 - pothole_level_accuracy: 0.8851 - val_loss: 1.4686 - val_pothole_loss: 0.8636 - val_pothole_level_loss: 0.6050 - val_pothole_accuracy: 0.8504 - val_pothole_level_accuracy: 0.8372
# Epoch 33/53
# 262/262 [==============================] - 130s 496ms/step - loss: 0.3762 - pothole_loss: 0.0658 - pothole_level_loss: 0.3105 - pothole_accuracy: 0.9742 - pothole_level_accuracy: 0.8852 - val_loss: 1.1661 - val_pothole_loss: 0.6935 - val_pothole_level_loss: 0.4726 - val_pothole_accuracy: 0.8485 - val_pothole_level_accuracy: 0.8580
# Epoch 34/53
# 262/262 [==============================] - 130s 497ms/step - loss: 0.3682 - pothole_loss: 0.0613 - pothole_level_loss: 0.3070 - pothole_accuracy: 0.9762 - pothole_level_accuracy: 0.8847 - val_loss: 26.3350 - val_pothole_loss: 0.7022 - val_pothole_level_loss: 25.6328 - val_pothole_accuracy: 0.8942 - val_pothole_level_accuracy: 0.7739
# Epoch 35/53
# 262/262 [==============================] - 131s 498ms/step - loss: 0.3665 - pothole_loss: 0.0631 - pothole_level_loss: 0.3034 - pothole_accuracy: 0.9751 - pothole_level_accuracy: 0.8864 - val_loss: 1.4145 - val_pothole_loss: 0.6500 - val_pothole_level_loss: 0.7646 - val_pothole_accuracy: 0.8592 - val_pothole_level_accuracy: 0.8488
# Epoch 36/53
# 262/262 [==============================] - 131s 499ms/step - loss: 0.3439 - pothole_loss: 0.0500 - pothole_level_loss: 0.2939 - pothole_accuracy: 0.9804 - pothole_level_accuracy: 0.8891 - val_loss: 1.5046 - val_pothole_loss: 0.7673 - val_pothole_level_loss: 0.7373 - val_pothole_accuracy: 0.8815 - val_pothole_level_accuracy: 0.8415
# Epoch 37/53
# 262/262 [==============================] - 130s 497ms/step - loss: 0.3308 - pothole_loss: 0.0464 - pothole_level_loss: 0.2844 - pothole_accuracy: 0.9823 - pothole_level_accuracy: 0.8930 - val_loss: 3.0780 - val_pothole_loss: 0.6548 - val_pothole_level_loss: 2.4233 - val_pothole_accuracy: 0.8569 - val_pothole_level_accuracy: 0.8377
# Epoch 38/53
# 262/262 [==============================] - 130s 496ms/step - loss: 0.3188 - pothole_loss: 0.0386 - pothole_level_loss: 0.2802 - pothole_accuracy: 0.9853 - pothole_level_accuracy: 0.8924 - val_loss: 4.1442 - val_pothole_loss: 0.7789 - val_pothole_level_loss: 3.3653 - val_pothole_accuracy: 0.8646 - val_pothole_level_accuracy: 0.8484
# Epoch 39/53
# 262/262 [==============================] - 130s 497ms/step - loss: 0.3150 - pothole_loss: 0.0421 - pothole_level_loss: 0.2729 - pothole_accuracy: 0.9838 - pothole_level_accuracy: 0.8956 - val_loss: 4.8948 - val_pothole_loss: 0.5853 - val_pothole_level_loss: 4.3095 - val_pothole_accuracy: 0.8788 - val_pothole_level_accuracy: 0.8525
# Epoch 40/53
# 262/262 [==============================] - 130s 495ms/step - loss: 0.3230 - pothole_loss: 0.0439 - pothole_level_loss: 0.2791 - pothole_accuracy: 0.9825 - pothole_level_accuracy: 0.8939 - val_loss: 1.3342 - val_pothole_loss: 0.7315 - val_pothole_level_loss: 0.6026 - val_pothole_accuracy: 0.8895 - val_pothole_level_accuracy: 0.8592
# Epoch 41/53
# 262/262 [==============================] - 130s 497ms/step - loss: 0.3172 - pothole_loss: 0.0443 - pothole_level_loss: 0.2730 - pothole_accuracy: 0.9835 - pothole_level_accuracy: 0.8957 - val_loss: 1.3578 - val_pothole_loss: 0.6921 - val_pothole_level_loss: 0.6657 - val_pothole_accuracy: 0.8913 - val_pothole_level_accuracy: 0.8547
# Epoch 42/53
# 262/262 [==============================] - 130s 496ms/step - loss: 0.3060 - pothole_loss: 0.0379 - pothole_level_loss: 0.2681 - pothole_accuracy: 0.9858 - pothole_level_accuracy: 0.8969 - val_loss: 2.8419 - val_pothole_loss: 0.7107 - val_pothole_level_loss: 2.1312 - val_pothole_accuracy: 0.8778 - val_pothole_level_accuracy: 0.7746
# Epoch 43/53
# 262/262 [==============================] - 130s 495ms/step - loss: 0.3008 - pothole_loss: 0.0342 - pothole_level_loss: 0.2666 - pothole_accuracy: 0.9877 - pothole_level_accuracy: 0.8984 - val_loss: 1.8566 - val_pothole_loss: 0.7537 - val_pothole_level_loss: 1.1028 - val_pothole_accuracy: 0.8670 - val_pothole_level_accuracy: 0.8118
# Epoch 44/53
# 262/262 [==============================] - 130s 495ms/step - loss: 0.3000 - pothole_loss: 0.0367 - pothole_level_loss: 0.2633 - pothole_accuracy: 0.9863 - pothole_level_accuracy: 0.8974 - val_loss: 1.6869 - val_pothole_loss: 0.8538 - val_pothole_level_loss: 0.8331 - val_pothole_accuracy: 0.8715 - val_pothole_level_accuracy: 0.8491
# Epoch 45/53
# 262/262 [==============================] - 130s 495ms/step - loss: 0.2854 - pothole_loss: 0.0302 - pothole_level_loss: 0.2551 - pothole_accuracy: 0.9885 - pothole_level_accuracy: 0.8985 - val_loss: 1.6418 - val_pothole_loss: 0.8756 - val_pothole_level_loss: 0.7662 - val_pothole_accuracy: 0.9002 - val_pothole_level_accuracy: 0.8471
# Epoch 46/53
# 262/262 [==============================] - 130s 495ms/step - loss: 0.2814 - pothole_loss: 0.0313 - pothole_level_loss: 0.2501 - pothole_accuracy: 0.9881 - pothole_level_accuracy: 0.9012 - val_loss: 1.6122 - val_pothole_loss: 0.7288 - val_pothole_level_loss: 0.8834 - val_pothole_accuracy: 0.8810 - val_pothole_level_accuracy: 0.8645
# Epoch 47/53
# 262/262 [==============================] - 130s 496ms/step - loss: 0.2790 - pothole_loss: 0.0317 - pothole_level_loss: 0.2474 - pothole_accuracy: 0.9883 - pothole_level_accuracy: 0.9024 - val_loss: 2.2134 - val_pothole_loss: 1.4010 - val_pothole_level_loss: 0.8125 - val_pothole_accuracy: 0.8337 - val_pothole_level_accuracy: 0.8131
# Epoch 48/53
# 262/262 [==============================] - 130s 497ms/step - loss: 0.2641 - pothole_loss: 0.0232 - pothole_level_loss: 0.2409 - pothole_accuracy: 0.9918 - pothole_level_accuracy: 0.9040 - val_loss: 1.5928 - val_pothole_loss: 0.8531 - val_pothole_level_loss: 0.7397 - val_pothole_accuracy: 0.9007 - val_pothole_level_accuracy: 0.8574
# Epoch 49/53
# 262/262 [==============================] - 130s 496ms/step - loss: 0.2559 - pothole_loss: 0.0238 - pothole_level_loss: 0.2322 - pothole_accuracy: 0.9913 - pothole_level_accuracy: 0.9080 - val_loss: 2.2615 - val_pothole_loss: 1.0236 - val_pothole_level_loss: 1.2379 - val_pothole_accuracy: 0.8982 - val_pothole_level_accuracy: 0.8469
# Epoch 50/53
# 262/262 [==============================] - 130s 495ms/step - loss: 0.2655 - pothole_loss: 0.0266 - pothole_level_loss: 0.2388 - pothole_accuracy: 0.9902 - pothole_level_accuracy: 0.9058 - val_loss: 1.3732 - val_pothole_loss: 0.8531 - val_pothole_level_loss: 0.5201 - val_pothole_accuracy: 0.8700 - val_pothole_level_accuracy: 0.8334
# Epoch 51/53
# 262/262 [==============================] - 130s 496ms/step - loss: 0.2544 - pothole_loss: 0.0276 - pothole_level_loss: 0.2269 - pothole_accuracy: 0.9900 - pothole_level_accuracy: 0.9107 - val_loss: 3.7326 - val_pothole_loss: 2.1105 - val_pothole_level_loss: 1.6221 - val_pothole_accuracy: 0.7727 - val_pothole_level_accuracy: 0.7816
# Epoch 52/53
# 262/262 [==============================] - 130s 496ms/step - loss: 0.2617 - pothole_loss: 0.0349 - pothole_level_loss: 0.2268 - pothole_accuracy: 0.9878 - pothole_level_accuracy: 0.9093 - val_loss: 3.3620 - val_pothole_loss: 1.9358 - val_pothole_level_loss: 1.4262 - val_pothole_accuracy: 0.8385 - val_pothole_level_accuracy: 0.8251
# Epoch 53/53
# 262/262 [==============================] - 130s 497ms/step - loss: 0.2393 - pothole_loss: 0.0180 - pothole_level_loss: 0.2213 - pothole_accuracy: 0.9940 - pothole_level_accuracy: 0.9123 - val_loss: 1.7319 - val_pothole_loss: 0.9988 - val_pothole_level_loss: 0.7331 - val_pothole_accuracy: 0.8792 - val_pothole_level_accuracy: 0.8587

# %%
# model.save("/content/gdrive/MyDrive/pothole_detection_model_prototype_9_adam.h5")

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

tflite_model_quant = converter.convert()
open("/content/gdrive/MyDrive/pothole_detection_model_prototype_9_adam_lite.tflite" , "wb").write(tflite_model_quant)
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input Layer with unsupported characters which will be renamed to placeholder in the SavedModel.
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 36260512

# %%
# import tensorflow as tf

# model = tf.keras.models.load_model('/content/gdrive/MyDrive/A_I/pothole_detection_model_prototype_1_adam.h5')
# converter = tf.lite.TFLiteConverter.from_keras_model(model)
# tflite_model = converter.convert()
# open("/content/gdrive/MyDrive/A_I/pothole_detection_model_prototype_1_adam.tflite", "wb").write(tflite_model)
